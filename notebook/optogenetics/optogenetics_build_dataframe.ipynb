# %% [markdown]
# # Optogenetics — Build Combined DataFrame
#
# This notebook is dedicated to (re)building the combined per-trial optogenetics DataFrame from NWB files and saving it to disk. Visualization lives in `optogenetics_visualization.ipynb`.

# %%
# =============================================================================
# 1. ENVIRONMENT SETUP & MODULE IMPORTS
# =============================================================================
"""
Initialize the analysis environment by loading essential modules and setting up
the Python path to access custom analysis functions.
"""

# Enable automatic reloading of modules for interactive development
# %load_ext autoreload
# %autoreload 2

# Import essential system modules
import sys
from pathlib import Path

# Define the path to custom analysis modules
# Note: Update this path to match your local installation
MODULE_PATH = Path("/root/capsule/src/aind_dft_ephys_analysis")

# Add module path to system path for importing custom functions
if str(MODULE_PATH) not in sys.path:
    sys.path.insert(0, str(MODULE_PATH))

print(f"✅ Analysis modules loaded from: {MODULE_PATH}")
print("🔄 Auto-reload enabled for interactive development")
# Out:
# ✅ Analysis modules loaded from: /root/capsule/src/aind_dft_ephys_analysis
# 🔄 Auto-reload enabled for interactive development

# %%
from optogenetics_utils import (
    create_opto_data_frame_combined,
    load_opto_data_frame,
)

# %% [markdown]
# ## Build / update the combined DataFrame
#
# Loads any existing combined CSV, then incrementally appends new sessions from the NWB folder and writes the result back to the same path.

# %%
combined_dataframe_o = load_opto_data_frame(
    csv_path='/root/capsule/scratch/combined_opto_data_frame.csv'
)

combined_dataframe = create_opto_data_frame_combined(
    save_path='/root/capsule/scratch/combined_opto_data_frame.csv',
    existing_data=combined_dataframe_o,
)

combined_dataframe.shape
# Out:
# Skipping 217 NWB file(s) already present in existing_data.
# Processing NWB files:   0%|          | 0/27 [00:00<?, ?file/s]
# [1/27] 850743_2026-06-22_11-24-25.nwb
# [2/27] 850743_2026-06-25_10-29-50.nwb
# /root/capsule/src/aind_dft_ephys_analysis/optogenetics_utils.py:245: UserWarning: [850743_2026-06-25_10-29-50.json] missing 33/33 latents.
#   warnings.warn(
# [3/27] 850743_2026-06-26_11-25-27.nwb
# [4/27] 850743_2026-06-29_10-25-54.nwb
# [5/27] 850743_2026-06-30_10-39-36.nwb
# /root/capsule/src/aind_dft_ephys_analysis/optogenetics_utils.py:245: UserWarning: [850743_2026-06-30_10-39-36.json] missing 27/33 latents.
#   warnings.warn(
# [6/27] 850743_2026-06-30_11-46-27.nwb
# /root/capsule/src/aind_dft_ephys_analysis/optogenetics_utils.py:245: UserWarning: [850743_2026-06-30_11-46-27.json] missing 27/33 latents.
#   warnings.warn(
# [7/27] 850743_2026-06-30_11-49-52.nwb
# [8/27] 850743_2026-07-01_10-10-49.nwb
# [9/27] 850743_2026-07-02_10-12-16.nwb
# [10/27] 850743_2026-07-07_09-57-39.nwb
# [11/27] 850743_2026-07-08_09-29-59.nwb
# [12/27] 850743_2026-07-13_11-43-08.nwb
# [13/27] 850743_2026-07-14_10-13-23.nwb
# [14/27] 850743_2026-07-15_10-46-13.nwb
# [15/27] 850743_2026-07-16_10-24-42.nwb
# [16/27] 850743_2026-07-17_10-13-28.nwb
# [17/27] 850743_2026-07-20_10-14-12.nwb
# [18/27] 850743_2026-07-21_09-52-33.nwb
# [19/27] 850743_2026-07-22_10-30-55.nwb
# [20/27] 850743_2026-07-23_11-07-52.nwb
# [21/27] 850743_2026-07-24_10-27-11.nwb
# [22/27] 850745_2026-06-25_10-22-17.nwb
# /root/capsule/src/aind_dft_ephys_analysis/optogenetics_utils.py:245: UserWarning: [850745_2026-06-25_10-22-17.json] missing 33/33 latents.
#   warnings.warn(
# [23/27] 850745_2026-06-26_09-59-19.nwb
# /root/capsule/src/aind_dft_ephys_analysis/optogenetics_utils.py:245: UserWarning: [850745_2026-06-26_09-59-19.json] missing 33/33 latents.
#   warnings.warn(
# [24/27] 850745_2026-06-29_10-18-16.nwb
# /root/capsule/src/aind_dft_ephys_analysis/optogenetics_utils.py:245: UserWarning: [850745_2026-06-29_10-18-16.json] missing 33/33 latents.
#   warnings.warn(
# [25/27] 850745_2026-06-30_10-28-30.nwb
# /root/capsule/src/aind_dft_ephys_analysis/optogenetics_utils.py:245: UserWarning: [850745_2026-06-30_10-28-30.json] missing 33/33 latents.
#   warnings.warn(
# [26/27] 850745_2026-07-01_10-15-51.nwb
# /root/capsule/src/aind_dft_ephys_analysis/optogenetics_utils.py:245: UserWarning: [850745_2026-07-01_10-15-51.json] missing 33/33 latents.
#   warnings.warn(
# [27/27] 850745_2026-07-02_09-53-55.nwb
# /root/capsule/src/aind_dft_ephys_analysis/optogenetics_utils.py:245: UserWarning: [850745_2026-07-02_09-53-55.json] missing 33/33 latents.
#   warnings.warn(
# Combined DataFrame saved to /root/capsule/scratch/combined_opto_data_frame.csv
# (112033, 133)
