# %% [markdown]
# # Optogenetics — Build Combined DataFrame
#
# This notebook is dedicated to (re)building the combined per-trial optogenetics DataFrame from NWB files and saving it to disk. Visualization lives in `optogenetics_visualization.ipynb`.

# %%
# =============================================================================
# 1. ENVIRONMENT SETUP & MODULE IMPORTS
# =============================================================================
"""
Initialize the analysis environment by loading essential modules and setting up
the Python path to access custom analysis functions.
"""

# Enable automatic reloading of modules for interactive development
# %load_ext autoreload
# %autoreload 2

# Import essential system modules
import sys
from pathlib import Path

# Define the path to custom analysis modules
# Note: Update this path to match your local installation
MODULE_PATH = Path("/root/capsule/src/aind_dft_ephys_analysis")

# Add module path to system path for importing custom functions
if str(MODULE_PATH) not in sys.path:
    sys.path.insert(0, str(MODULE_PATH))

print(f"✅ Analysis modules loaded from: {MODULE_PATH}")
print("🔄 Auto-reload enabled for interactive development")
# Out:
# ✅ Analysis modules loaded from: /root/capsule/src/aind_dft_ephys_analysis
# 🔄 Auto-reload enabled for interactive development

# %%
from optogenetics_utils import (
    create_opto_data_frame_combined,
    load_opto_data_frame,
)

# %% [markdown]
# ## Build / update the combined DataFrame
#
# Loads any existing combined CSV, then incrementally appends new sessions from the NWB folder and writes the result back to the same path.

# %%
combined_dataframe_o = load_opto_data_frame(
    csv_path='/root/capsule/scratch/combined_opto_data_frame.csv'
)

combined_dataframe = create_opto_data_frame_combined(
    save_path='/root/capsule/scratch/combined_opto_data_frame.csv',
    existing_data=combined_dataframe_o,
)

combined_dataframe.shape
# Out:
# Skipping 183 NWB file(s) already present in existing_data.
# Processing NWB files:   0%|          | 0/21 [00:00<?, ?file/s]
# [1/21] 856494_2026-07-13_13-29-24.nwb
# /root/capsule/src/aind_dft_ephys_analysis/optogenetics_utils.py:245: UserWarning: [856494_2026-07-13_13-29-24.json] missing 33/33 latents.
#   warnings.warn(
# [2/21] 856494_2026-07-14_15-21-03.nwb
# /root/capsule/src/aind_dft_ephys_analysis/optogenetics_utils.py:245: UserWarning: [856494_2026-07-14_15-21-03.json] missing 33/33 latents.
#   warnings.warn(
# [3/21] 856494_2026-07-15_14-36-16.nwb
# /root/capsule/src/aind_dft_ephys_analysis/optogenetics_utils.py:245: UserWarning: [856494_2026-07-15_14-36-16.json] missing 33/33 latents.
#   warnings.warn(
# [4/21] 856494_2026-07-16_15-41-18.nwb
# /root/capsule/src/aind_dft_ephys_analysis/optogenetics_utils.py:245: UserWarning: [856494_2026-07-16_15-41-18.json] missing 33/33 latents.
#   warnings.warn(
# [5/21] 856494_2026-07-17_16-45-46.nwb
# /root/capsule/src/aind_dft_ephys_analysis/optogenetics_utils.py:245: UserWarning: [856494_2026-07-17_16-45-46.json] missing 33/33 latents.
#   warnings.warn(
# [6/21] 856494_2026-07-20_13-56-55.nwb
# /root/capsule/src/aind_dft_ephys_analysis/optogenetics_utils.py:245: UserWarning: [856494_2026-07-20_13-56-55.json] missing 33/33 latents.
#   warnings.warn(
# [7/21] 856494_2026-07-21_16-23-56.nwb
# /root/capsule/src/aind_dft_ephys_analysis/optogenetics_utils.py:245: UserWarning: [856494_2026-07-21_16-23-56.json] missing 33/33 latents.
#   warnings.warn(
# [8/21] 856494_2026-07-23_15-17-01.nwb
# /root/capsule/src/aind_dft_ephys_analysis/optogenetics_utils.py:245: UserWarning: [856494_2026-07-23_15-17-01.json] missing 33/33 latents.
#   warnings.warn(
# [9/21] 856494_2026-07-24_14-42-22.nwb
# /root/capsule/src/aind_dft_ephys_analysis/optogenetics_utils.py:245: UserWarning: [856494_2026-07-24_14-42-22.json] missing 33/33 latents.
#   warnings.warn(
# [10/21] 856494_2026-07-28_16-13-05.nwb
# /root/capsule/src/aind_dft_ephys_analysis/optogenetics_utils.py:245: UserWarning: [856494_2026-07-28_16-13-05.json] missing 33/33 latents.
#   warnings.warn(
# [11/21] 856494_2026-07-29_16-02-03.nwb
# /root/capsule/src/aind_dft_ephys_analysis/optogenetics_utils.py:245: UserWarning: [856494_2026-07-29_16-02-03.json] missing 33/33 latents.
#   warnings.warn(
# [12/21] 856494_2026-07-30_15-17-23.nwb
# /root/capsule/src/aind_dft_ephys_analysis/optogenetics_utils.py:245: UserWarning: [856494_2026-07-30_15-17-23.json] missing 33/33 latents.
#   warnings.warn(
# [13/21] 856494_2026-08-03_13-52-18.nwb
# /root/capsule/src/aind_dft_ephys_analysis/optogenetics_utils.py:245: UserWarning: [856494_2026-08-03_13-52-18.json] missing 33/33 latents.
#   warnings.warn(
# [14/21] 856494_2026-08-05_13-49-05.nwb
# /root/capsule/src/aind_dft_ephys_analysis/optogenetics_utils.py:245: UserWarning: [856494_2026-08-05_13-49-05.json] missing 33/33 latents.
#   warnings.warn(
# [15/21] 858399_2026-07-27_10-18-06.nwb
# [16/21] 858399_2026-07-28_11-10-49.nwb
# [17/21] 858399_2026-07-29_12-25-53.nwb
# [18/21] 858399_2026-07-30_11-46-31.nwb
# [19/21] 858399_2026-07-31_09-42-07.nwb
# [20/21] 858399_2026-08-03_09-47-31.nwb
# [21/21] 858399_2026-08-05_09-50-03.nwb
# Combined DataFrame saved to /root/capsule/scratch/combined_opto_data_frame.csv
# (93792, 133)
