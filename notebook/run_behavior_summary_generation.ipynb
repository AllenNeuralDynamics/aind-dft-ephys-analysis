# %%
# import essential
import sys
from pathlib import Path

MODULE_PATH = Path("/root/capsule/src/aind_dft_ephys_analysis")

if str(MODULE_PATH) not in sys.path:
    sys.path.insert(0, str(MODULE_PATH))

# %%
from behavior_utils import generate_behavior_summary_combined
from general_utils import find_ephys_sessions
from general_utils import smart_read_csv
import pandas as pd
from ephys_behavior import (
    get_the_mean_firing_rate_combined,   # ← updated name here
    correlate_firing_latent_multiple_variable
)
import os

# 1) find your sorted sessions
_, _, spike_sorted_sessions = find_ephys_sessions()
print("Sessions to process:", spike_sorted_sessions)


# 3) ensure results folder
results_folder = '/root/capsule/scratch/behavior_summary'
os.makedirs(results_folder, exist_ok=True)

# 4) iterate sessions
for sess in spike_sorted_sessions:
    try:
        print(f"\n=== Processing session {sess} ===")

        # a) behavior summary
        generate_behavior_summary_combined(
            session_names=[sess],
            save_result=True,
            save_folder=results_folder,
            save_name=f"behavior_summary-{sess}.csv"
        )

    except Exception as e:
        print(f"!! Error in session {sess}: {e}")
        continue

# %%
from general_visualization import plot_behavior_session
from nwb_utils import NWBUtils
from behavior_utils import get_fitted_model_names
from general_utils import find_behavior_sessions

import os

folder_path = '/root/capsule/data/behavior_nwb'  # Replace with your folder path

# List only files (exclude subdirectories)
behavior_sessions = [f for f in os.listdir(folder_path)
         if os.path.isfile(os.path.join(folder_path, f))]


behavior_sessions=['ecephys_795396_2025-09-20_13-11-19_sorted_2025-10-29_20-43-11']
for behavior_session in behavior_sessions:
        nwb_data=NWBUtils.read_behavior_nwb(session_name=behavior_session)
        plot_behavior_session(nwb_data=nwb_data,model_alias='ForagingCompareThreshold',latent_name='right_choice_probability')

# %%
nwb_data=NWBUtils.read_behavior_nwb(session_name=behavior_session)

# %%
# Generate behavior summaries for a specific list of sessions
from behavior_utils import generate_behavior_summary_combined
import os

from general_utils import find_ephys_sessions
from general_utils import smart_read_csv
import pandas as pd
from ephys_behavior import (
    get_the_mean_firing_rate_combined,   # ← updated name here
    correlate_firing_latent_multiple_variable
)
import os



results_folder = "/root/capsule/scratch/behavior_summary"
os.makedirs(results_folder, exist_ok=True)

sessions = [
    "ecephys_839480_2026-06-02_16-20-58_sorted_2026-06-09_15-56-14",
    "ecephys_839480_2026-06-03_15-09-14_sorted-bandpass_2026-07-18_00-07-17",
    "ecephys_839480_2026-06-04_13-45-44_sorted-bandpass_2026-07-17_22-26-58",
    "ecephys_839480_2026-06-05_14-36-28_sorted-bandpass_2026-07-18_00-37-38",
    "ecephys_839483_2026-05-26_16-02-39_sorted_2026-06-09_09-42-36",
    "ecephys_839483_2026-05-28_14-47-06_sorted-bandpass_2026-07-17_20-18-46",
]

for sess in sessions:
    try:
        print(f"\n=== Processing session {sess} ===")
        generate_behavior_summary_combined(
            session_names=[sess],
            save_result=True,
            save_folder=results_folder,
            save_name=f"behavior_summary-{sess}.csv",
        )
    except Exception as e:
        print(f"!! Error in session {sess}: {e}")
        continue
# Out:
# === Processing session ecephys_839480_2026-06-02_16-20-58_sorted_2026-06-09_15-56-14 ===
# Warning: No folder matching '*839480_2026-06-02_16-20-58_*processed*' found under ['/root/capsule/data/'].
# Found behavior NWB: /root/capsule/data/behavior_nwb/839480_2026-06-02_16-20-58.nwb
# Successfully read behavior NWB from: /root/capsule/data/behavior_nwb/839480_2026-06-02_16-20-58.nwb
# 2026-08-03 21:56:41,588 - aind_dynamic_foraging_models.generative_model.base - INFO - Fitting the model using the whole dataset...
# Can't extract right_choice_probability from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract right_choice_probability-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract right_choice_probability+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract left_choice_probability from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract left_choice_probability-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract left_choice_probability+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract QL from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QL-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QL+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QR from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QR-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QR+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract chosenQ from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract chosenQ-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract chosenQ+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract unchosenQ from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract unchosenQ-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract unchosenQ+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# No model-fitting results for subject 839480 on 2026-06-02
# Combined summary saved to /root/capsule/scratch/behavior_summary/behavior_summary-ecephys_839480_2026-06-02_16-20-58_sorted_2026-06-09_15-56-14.csv
#
# === Processing session ecephys_839480_2026-06-03_15-09-14_sorted-bandpass_2026-07-18_00-07-17 ===
# Warning: No folder matching '*839480_2026-06-03_15-09-14_*processed*' found under ['/root/capsule/data/'].
# Found behavior NWB: /root/capsule/data/behavior_nwb/839480_2026-06-03_15-09-14.nwb
# Successfully read behavior NWB from: /root/capsule/data/behavior_nwb/839480_2026-06-03_15-09-14.nwb
# 2026-08-03 21:56:48,095 - aind_dynamic_foraging_models.generative_model.base - INFO - Fitting the model using the whole dataset...
# Can't extract right_choice_probability from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract right_choice_probability-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract right_choice_probability+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract left_choice_probability from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract left_choice_probability-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract left_choice_probability+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract QL from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QL-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QL+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QR from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QR-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QR+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract chosenQ from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract chosenQ-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract chosenQ+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract unchosenQ from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract unchosenQ-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract unchosenQ+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# No model-fitting results for subject 839480 on 2026-06-03
# Combined summary saved to /root/capsule/scratch/behavior_summary/behavior_summary-ecephys_839480_2026-06-03_15-09-14_sorted-bandpass_2026-07-18_00-07-17.csv
#
# === Processing session ecephys_839480_2026-06-04_13-45-44_sorted-bandpass_2026-07-17_22-26-58 ===
# Warning: No folder matching '*839480_2026-06-04_13-45-44_*processed*' found under ['/root/capsule/data/'].
# Found behavior NWB: /root/capsule/data/behavior_nwb/839480_2026-06-04_13-45-44.nwb
# Successfully read behavior NWB from: /root/capsule/data/behavior_nwb/839480_2026-06-04_13-45-44.nwb
# 2026-08-03 21:56:57,522 - aind_dynamic_foraging_models.generative_model.base - INFO - Fitting the model using the whole dataset...
# Can't extract right_choice_probability from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract right_choice_probability-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract right_choice_probability+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract left_choice_probability from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract left_choice_probability-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract left_choice_probability+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract QL from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QL-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QL+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QR from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QR-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QR+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract chosenQ from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract chosenQ-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract chosenQ+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract unchosenQ from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract unchosenQ-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract unchosenQ+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# No model-fitting results for subject 839480 on 2026-06-04
# Combined summary saved to /root/capsule/scratch/behavior_summary/behavior_summary-ecephys_839480_2026-06-04_13-45-44_sorted-bandpass_2026-07-17_22-26-58.csv
#
# === Processing session ecephys_839480_2026-06-05_14-36-28_sorted-bandpass_2026-07-18_00-37-38 ===
# Warning: No folder matching '*839480_2026-06-05_14-36-28_*processed*' found under ['/root/capsule/data/'].
# Found behavior NWB: /root/capsule/data/behavior_nwb/839480_2026-06-05_14-36-28.nwb
# Successfully read behavior NWB from: /root/capsule/data/behavior_nwb/839480_2026-06-05_14-36-28.nwb
# 2026-08-03 21:57:09,323 - aind_dynamic_foraging_models.generative_model.base - INFO - Fitting the model using the whole dataset...
# Can't extract right_choice_probability from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract right_choice_probability-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract right_choice_probability+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract left_choice_probability from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract left_choice_probability-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract left_choice_probability+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract QL from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QL-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QL+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QR from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QR-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QR+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract chosenQ from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract chosenQ-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract chosenQ+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract unchosenQ from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract unchosenQ-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract unchosenQ+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# No model-fitting results for subject 839480 on 2026-06-05
# Combined summary saved to /root/capsule/scratch/behavior_summary/behavior_summary-ecephys_839480_2026-06-05_14-36-28_sorted-bandpass_2026-07-18_00-37-38.csv
#
# === Processing session ecephys_839483_2026-05-26_16-02-39_sorted_2026-06-09_09-42-36 ===
# Warning: No folder matching '*839483_2026-05-26_16-02-39_*processed*' found under ['/root/capsule/data/'].
# Warning: No behavior NWB files found for session '839483_2026-05-26_16-02-39' under ['/root/capsule/data/behavior_nwb', '/root/capsule/data/optogenetics_nwb'].
# Warning: could not load session ecephys_839483_2026-05-26_16-02-39_sorted_2026-06-09_09-42-36, skipping.
# Combined summary saved to /root/capsule/scratch/behavior_summary/behavior_summary-ecephys_839483_2026-05-26_16-02-39_sorted_2026-06-09_09-42-36.csv
#
# === Processing session ecephys_839483_2026-05-28_14-47-06_sorted-bandpass_2026-07-17_20-18-46 ===
# Warning: No folder matching '*839483_2026-05-28_14-47-06_*processed*' found under ['/root/capsule/data/'].
# Found behavior NWB: /root/capsule/data/behavior_nwb/839483_2026-05-28_14-47-06.nwb
# 2026-08-03 21:57:22,860 - aind_dynamic_foraging_models.generative_model.base - INFO - Fitting the model using the whole dataset...
# Successfully read behavior NWB from: /root/capsule/data/behavior_nwb/839483_2026-05-28_14-47-06.nwb
# Can't extract right_choice_probability from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract right_choice_probability-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract right_choice_probability+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract left_choice_probability from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract left_choice_probability-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract left_choice_probability+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'choice_prob'
# Can't extract QL from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QL-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QL+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QR from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QR-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract QR+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract chosenQ from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract chosenQ-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract chosenQ+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract unchosenQ from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract unchosenQ-1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# Can't extract unchosenQ+1 from ForagingCompareThreshold_L1_ResetF_StayBiasT_FixThrT0: 'NoneType' object is not subscriptable
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# No model-fitting results for subject 839483 on 2026-05-28
# Combined summary saved to /root/capsule/scratch/behavior_summary/behavior_summary-ecephys_839483_2026-05-28_14-47-06_sorted-bandpass_2026-07-17_20-18-46.csv
