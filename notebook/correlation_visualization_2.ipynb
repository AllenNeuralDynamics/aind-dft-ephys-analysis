# %%
# =============================================================================
# 1. ENVIRONMENT SETUP & MODULE IMPORTS
# =============================================================================
"""
Initialize the analysis environment by loading essential modules and setting up
the Python path to access custom analysis functions.
"""

# Enable automatic reloading of modules for interactive development
# %load_ext autoreload
# %autoreload 2

# Import essential system modules
import sys
from pathlib import Path

# Define the path to custom analysis modules
# Note: Update this path to match your local installation
MODULE_PATH = Path("/root/capsule/src/aind_dft_ephys_analysis")

# Add module path to system path for importing custom functions
if str(MODULE_PATH) not in sys.path:
    sys.path.insert(0, str(MODULE_PATH))

print(f"✅ Analysis modules loaded from: {MODULE_PATH}")
print("🔄 Auto-reload enabled for interactive development")
# Out:
# ✅ Analysis modules loaded from: /root/capsule/src/aind_dft_ephys_analysis
# 🔄 Auto-reload enabled for interactive development

# %%
from ephys_behavior import correlation_results_summary_combined

# 1) Let the function discover every correlations CSV automatically
summary = correlation_results_summary_combined(
    save_result=True,                       # write to disk
    save_name='sig_dir_all_sessions',    # custom file name
    search_folder='/root/capsule/scratch/correlation_deltaQ_sumQ_value/',
    save_folder='/root/capsule/scratch/correlation_deltaQ_sumQ_value/',
)
# Out:
# Found 38 correlation result file(s)/folder(s):
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_753124_2024-12-10_17-24-56_sorted_2024-12-13_09-48-25.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_753125_2024-10-09_10-50-19_sorted_2024-11-09_20-03-58.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_753125_2024-10-10_14-41-23_sorted_2024-11-09_20-18-36.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_753125_2024-10-14_15-37-15_sorted_2024-11-09_20-07-38.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_753125_2024-10-15_16-16-22_sorted_2024-11-09_19-57-50.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_753126_2024-10-10_17-51-24_sorted_2025-02-21_13-56-40.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_753126_2024-10-11_13-14-24_sorted_2024-11-09_19-18-21.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_753126_2024-10-15_12-20-35_sorted_2024-11-09_19-47-57.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_764769_2024-12-11_18-21-49_sorted_2024-12-13_10-04-48.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_764769_2024-12-12_16-05-00_sorted_2024-12-13_10-34-23.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_764769_2024-12-13_15-41-07_sorted_2024-12-17_18-00-23.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_764787_2024-12-11_15-01-15_sorted_2025-02-21_17-11-57.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_764787_2024-12-12_11-54-14_sorted_2024-12-13_10-39-18.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_764787_2024-12-13_18-27-42_sorted_2024-12-17_18-31-24.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_764790_2024-12-17_16-57-52_sorted_2024-12-20_18-46-41.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_764790_2024-12-18_12-14-41_sorted_2024-12-21_23-37-20.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_764790_2024-12-19_16-11-34_sorted_2025-02-21_14-46-33.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_764790_2024-12-20_16-56-37_sorted_2024-12-22_00-06-37.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_764791_2025-01-14_12-04-05_sorted_2025-04-24_18-24-08.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_764791_2025-01-16_12-50-17_sorted_2025-04-25_14-11-37.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_769884_2025-01-14_14-53-24_sorted_2025-01-24_14-20-13.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_769884_2025-01-15_16-12-59_sorted_2025-04-24_17-11-57.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_769884_2025-01-16_18-33-11_sorted_2025-04-24_19-24-23.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_776293_2025-02-14_15-19-17_sorted_2025-02-28_21-37-07.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_776293_2025-02-18_12-51-36_sorted_2025-03-30_05-50-33.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_776293_2025-02-19_14-01-07_sorted_2025-03-30_08-55-28.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_776293_2025-02-20_14-03-10_sorted_2025-03-30_03-39-17.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_780618_2025-04-15_13-30-58_sorted_2025-04-18_12-52-04.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_780618_2025-04-16_15-54-21_sorted_2025-04-18_12-51-23.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_780618_2025-04-17_13-48-57_sorted_2025-11-07_16-27-28.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_781469_2025-03-27_18-45-35_sorted_2025-03-30_16-18-11.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_781469_2025-03-29_10-46-53_sorted_2025-03-30_05-48-42.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_781471_2025-03-27_13-39-06_sorted_2025-03-31_11-52-53.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_781471_2025-03-28_15-06-14_sorted_2025-03-31_14-10-16.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_781471_2025-03-31_14-33-03_sorted_2025-04-01_15-50-16.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_795393_2025-09-11_20-05-17_sorted_2025-10-29_15-06-02.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_795393_2025-09-15_13-05-25_sorted_2025-10-29_20-10-36.zarr
#   • /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_795396_2025-09-20_13-11-19_sorted_2025-10-29_20-43-11.zarr
#
# [ 1/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_753124_2024-12-10_17-24-56_sorted_2024-12-13_09-48-25.zarr …
#
# [ 2/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_753125_2024-10-09_10-50-19_sorted_2024-11-09_20-03-58.zarr …
#
# [ 3/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_753125_2024-10-10_14-41-23_sorted_2024-11-09_20-18-36.zarr …
#
# [ 4/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_753125_2024-10-14_15-37-15_sorted_2024-11-09_20-07-38.zarr …
#
# [ 5/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_753125_2024-10-15_16-16-22_sorted_2024-11-09_19-57-50.zarr …
#
# [ 6/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_753126_2024-10-10_17-51-24_sorted_2025-02-21_13-56-40.zarr …
#
# [ 7/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_753126_2024-10-11_13-14-24_sorted_2024-11-09_19-18-21.zarr …
#
# [ 8/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_753126_2024-10-15_12-20-35_sorted_2024-11-09_19-47-57.zarr …
#
# [ 9/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_764769_2024-12-11_18-21-49_sorted_2024-12-13_10-04-48.zarr …
#
# [ 10/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_764769_2024-12-12_16-05-00_sorted_2024-12-13_10-34-23.zarr …
#
# [ 11/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_764769_2024-12-13_15-41-07_sorted_2024-12-17_18-00-23.zarr …
#
# [ 12/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_764787_2024-12-11_15-01-15_sorted_2025-02-21_17-11-57.zarr …
#
# [ 13/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_764787_2024-12-12_11-54-14_sorted_2024-12-13_10-39-18.zarr …
#
# [ 14/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_764787_2024-12-13_18-27-42_sorted_2024-12-17_18-31-24.zarr …
#
# [ 15/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_764790_2024-12-17_16-57-52_sorted_2024-12-20_18-46-41.zarr …
#
# [ 16/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_764790_2024-12-18_12-14-41_sorted_2024-12-21_23-37-20.zarr …
#
# [ 17/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_764790_2024-12-19_16-11-34_sorted_2025-02-21_14-46-33.zarr …
#
# [ 18/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_764790_2024-12-20_16-56-37_sorted_2024-12-22_00-06-37.zarr …
#
# [ 19/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_764791_2025-01-14_12-04-05_sorted_2025-04-24_18-24-08.zarr …
#
# [ 20/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_764791_2025-01-16_12-50-17_sorted_2025-04-25_14-11-37.zarr …
#
# [ 21/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_769884_2025-01-14_14-53-24_sorted_2025-01-24_14-20-13.zarr …
#
# [ 22/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_769884_2025-01-15_16-12-59_sorted_2025-04-24_17-11-57.zarr …
#
# [ 23/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_769884_2025-01-16_18-33-11_sorted_2025-04-24_19-24-23.zarr …
#
# [ 24/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_776293_2025-02-14_15-19-17_sorted_2025-02-28_21-37-07.zarr …
#
# [ 25/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_776293_2025-02-18_12-51-36_sorted_2025-03-30_05-50-33.zarr …
#
# [ 26/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_776293_2025-02-19_14-01-07_sorted_2025-03-30_08-55-28.zarr …
#
# [ 27/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_776293_2025-02-20_14-03-10_sorted_2025-03-30_03-39-17.zarr …
#
# [ 28/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_780618_2025-04-15_13-30-58_sorted_2025-04-18_12-52-04.zarr …
#
# [ 29/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_780618_2025-04-16_15-54-21_sorted_2025-04-18_12-51-23.zarr …
#
# [ 30/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_780618_2025-04-17_13-48-57_sorted_2025-11-07_16-27-28.zarr …
#
# [ 31/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_781469_2025-03-27_18-45-35_sorted_2025-03-30_16-18-11.zarr …
#
# [ 32/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_781469_2025-03-29_10-46-53_sorted_2025-03-30_05-48-42.zarr …
#
# [ 33/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_781471_2025-03-27_13-39-06_sorted_2025-03-31_11-52-53.zarr …
#
# [ 34/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_781471_2025-03-28_15-06-14_sorted_2025-03-31_14-10-16.zarr …
#
# [ 35/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_781471_2025-03-31_14-33-03_sorted_2025-04-01_15-50-16.zarr …
#
# [ 36/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_795393_2025-09-11_20-05-17_sorted_2025-10-29_15-06-02.zarr …
#
# [ 37/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_795393_2025-09-15_13-05-25_sorted_2025-10-29_20-10-36.zarr …
#
# [ 38/38 ]  Processing /root/capsule/scratch/correlation_deltaQ_sumQ_value/correlations_multi-ecephys_795396_2025-09-20_13-11-19_sorted_2025-10-29_20-43-11.zarr …
# [multi-var] combined summary written to /root/capsule/scratch/correlation_deltaQ_sumQ_value/sig_dir_all_sessions.zarr

# %%
from general_utils import load_temporary_data

# path that you passed as   save_folder / (save_name + ".csv")
zarr_path = "/root/capsule/scratch/correlation_deltaQ_sumQ_value/sig_dir_all_sessions.zarr"
ds = load_temporary_data(zarr_path)



print("Rows:", len(ds))
display(ds.head())             # in a notebook
# Out:
# Rows: 72816
#       brain_region                                       ccf_location  \
# index
# 0                   {'best_electrode': 1, 'shank': 0, 'probe': 'Pr...
# 1                   {'best_electrode': 1, 'shank': 0, 'probe': 'Pr...
# 2                   {'best_electrode': 1, 'shank': 0, 'probe': 'Pr...
# 3                   {'best_electrode': 7, 'shank': 0, 'probe': 'Pr...
# 4                   {'best_electrode': 7, 'shank': 0, 'probe': 'Pr...
#
#                                             fit_metadata  \
# index
# 0      {'simple_LR-g0-s0-d0': {'fit_parameters': {'ad...
# 1      {'simple_LR-g0-s0-d0': {'fit_parameters': {'ad...
# 2      {'simple_LR-g0-s0-d0': {'fit_parameters': {'ad...
# 3      {'simple_LR-g0-s0-d0': {'fit_parameters': {'ad...
# 4      {'simple_LR-g0-s0-d0': {'fit_parameters': {'ad...
#
#                        session_id  \
# index
# 0      753124_2024-12-10_17-24-56
# 1      753124_2024-12-10_17-24-56
# 2      753124_2024-12-10_17-24-56
# 3      753124_2024-12-10_17-24-56
# 4      753124_2024-12-10_17-24-56
#
#        simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-coef  \
# index
# 0                                               0.424205
# 1                                              -0.092121
# 2                                              -0.516326
# 3                                               0.883072
# 4                                               0.801632
#
#        simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-pval  \
# index
# 0                                               0.193132
# 1                                               0.709527
# 2                                               0.021303
# 3                                               0.005235
# 4                                               0.001122
#
#        simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-tval  \
# index
# 0                                               1.303823
# 1                                              -0.372787
# 2                                              -2.312740
# 3                                               2.809463
# 4                                               3.284619
#
#        simple_LR-ForagingCompareThreshold-value-1-g5-s0-d0-coef  \
# index
# 0                                               0.843576
# 1                                               0.213103
# 2                                              -0.630473
# 3                                               1.147668
# 4                                               1.024035
#
#        simple_LR-ForagingCompareThreshold-value-1-g5-s0-d0-pval  \
# index
# 0                                           3.469985e-05
# 1                                           1.911810e-01
# 2                                           3.302872e-03
# 3                                           2.880177e-05
# 4                                           7.860853e-07
#
#        simple_LR-ForagingCompareThreshold-value-1-g5-s0-d0-tval  ...  \
# index                                                            ...
# 0                                               4.193396         ...
# 1                                               1.309577         ...
# 2                                              -2.957988         ...
# 3                                               4.237539         ...
# 4                                               5.027984         ...
#
#        simple_LR-g7-s0-d0-f_stat  simple_LR-g7-s0-d0-hqic  \
# index
# 0                     241.923952                      NaN
# 1                     158.419861                      NaN
# 2                      35.735636                      NaN
# 3                     111.809485                      NaN
# 4                     135.077758                      NaN
#
#        simple_LR-g7-s0-d0-llf  simple_LR-g7-s0-d0-rsq  \
# index
# 0                 -582.425023                0.670910
# 1                 -530.031899                0.571734
# 2                 -601.334342                0.231445
# 3                 -653.643746                0.485124
# 4                 -546.665232                0.532338
#
#        simple_LR-g7-s0-d0-rsq_adj  simple_LR-g7-s0-d0-sigma2  \
# index
# 0                        0.668137                        NaN
# 1                        0.568125                        NaN
# 2                        0.224968                        NaN
# 3                        0.480785                        NaN
# 4                        0.528397                        NaN
#
#                                              source_file  time_window  \
# index
# 0      correlations_multi-ecephys_753124_2024-12-10_1...         -1_0
# 1      correlations_multi-ecephys_753124_2024-12-10_1...        0.3_2
# 2      correlations_multi-ecephys_753124_2024-12-10_1...   0.3_2_-1_0
# 3      correlations_multi-ecephys_753124_2024-12-10_1...         -1_0
# 4      correlations_multi-ecephys_753124_2024-12-10_1...        0.3_2
#
#        unit_index  z_score
# index
# 0               9    False
# 1               9    False
# 2               9    False
# 3              14    False
# 4              14    False
#
# [5 rows x 122 columns]

# %%
for i in ds.columns:
    print(i)
# Out:
# brain_region
# ccf_location
# fit_metadata
# session_id
# simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-coef
# simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-pval
# simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-tval
# simple_LR-ForagingCompareThreshold-value-1-g5-s0-d0-coef
# simple_LR-ForagingCompareThreshold-value-1-g5-s0-d0-pval
# simple_LR-ForagingCompareThreshold-value-1-g5-s0-d0-tval
# simple_LR-ForagingCompareThreshold-value-1-g6-s0-d0-coef
# simple_LR-ForagingCompareThreshold-value-1-g6-s0-d0-pval
# simple_LR-ForagingCompareThreshold-value-1-g6-s0-d0-tval
# simple_LR-ForagingCompareThreshold-value-1-g7-s0-d0-coef
# simple_LR-ForagingCompareThreshold-value-1-g7-s0-d0-pval
# simple_LR-ForagingCompareThreshold-value-1-g7-s0-d0-tval
# simple_LR-QLearning_L1F1_CK1_softmax-deltaQ-1-g1-s0-d0-coef
# simple_LR-QLearning_L1F1_CK1_softmax-deltaQ-1-g1-s0-d0-pval
# simple_LR-QLearning_L1F1_CK1_softmax-deltaQ-1-g1-s0-d0-tval
# simple_LR-QLearning_L1F1_CK1_softmax-deltaQ-1-g3-s0-d0-coef
# simple_LR-QLearning_L1F1_CK1_softmax-deltaQ-1-g3-s0-d0-pval
# simple_LR-QLearning_L1F1_CK1_softmax-deltaQ-1-g3-s0-d0-tval
# simple_LR-QLearning_L1F1_CK1_softmax-deltaQ-1-g4-s0-d0-coef
# simple_LR-QLearning_L1F1_CK1_softmax-deltaQ-1-g4-s0-d0-pval
# simple_LR-QLearning_L1F1_CK1_softmax-deltaQ-1-g4-s0-d0-tval
# simple_LR-QLearning_L1F1_CK1_softmax-deltaQ-1-g6-s0-d0-coef
# simple_LR-QLearning_L1F1_CK1_softmax-deltaQ-1-g6-s0-d0-pval
# simple_LR-QLearning_L1F1_CK1_softmax-deltaQ-1-g6-s0-d0-tval
# simple_LR-QLearning_L1F1_CK1_softmax-deltaQ-1-g7-s0-d0-coef
# simple_LR-QLearning_L1F1_CK1_softmax-deltaQ-1-g7-s0-d0-pval
# simple_LR-QLearning_L1F1_CK1_softmax-deltaQ-1-g7-s0-d0-tval
# simple_LR-QLearning_L1F1_CK1_softmax-sumQ-1-g0-s0-d0-coef
# simple_LR-QLearning_L1F1_CK1_softmax-sumQ-1-g0-s0-d0-pval
# simple_LR-QLearning_L1F1_CK1_softmax-sumQ-1-g0-s0-d0-tval
# simple_LR-QLearning_L1F1_CK1_softmax-sumQ-1-g3-s0-d0-coef
# simple_LR-QLearning_L1F1_CK1_softmax-sumQ-1-g3-s0-d0-pval
# simple_LR-QLearning_L1F1_CK1_softmax-sumQ-1-g3-s0-d0-tval
# simple_LR-QLearning_L1F1_CK1_softmax-sumQ-1-g4-s0-d0-coef
# simple_LR-QLearning_L1F1_CK1_softmax-sumQ-1-g4-s0-d0-pval
# simple_LR-QLearning_L1F1_CK1_softmax-sumQ-1-g4-s0-d0-tval
# simple_LR-QLearning_L1F1_CK1_softmax-sumQ-1-g5-s0-d0-coef
# simple_LR-QLearning_L1F1_CK1_softmax-sumQ-1-g5-s0-d0-pval
# simple_LR-QLearning_L1F1_CK1_softmax-sumQ-1-g5-s0-d0-tval
# simple_LR-QLearning_L1F1_CK1_softmax-sumQ-1-g7-s0-d0-coef
# simple_LR-QLearning_L1F1_CK1_softmax-sumQ-1-g7-s0-d0-pval
# simple_LR-QLearning_L1F1_CK1_softmax-sumQ-1-g7-s0-d0-tval
# simple_LR-g0-s0-d0-aic
# simple_LR-g0-s0-d0-bic
# simple_LR-g0-s0-d0-f_pvalue
# simple_LR-g0-s0-d0-f_stat
# simple_LR-g0-s0-d0-hqic
# simple_LR-g0-s0-d0-llf
# simple_LR-g0-s0-d0-rsq
# simple_LR-g0-s0-d0-rsq_adj
# simple_LR-g0-s0-d0-sigma2
# simple_LR-g1-s0-d0-aic
# simple_LR-g1-s0-d0-bic
# simple_LR-g1-s0-d0-f_pvalue
# simple_LR-g1-s0-d0-f_stat
# simple_LR-g1-s0-d0-hqic
# simple_LR-g1-s0-d0-llf
# simple_LR-g1-s0-d0-rsq
# simple_LR-g1-s0-d0-rsq_adj
# simple_LR-g1-s0-d0-sigma2
# simple_LR-g2-s0-d0-aic
# simple_LR-g2-s0-d0-bic
# simple_LR-g2-s0-d0-f_pvalue
# simple_LR-g2-s0-d0-f_stat
# simple_LR-g2-s0-d0-hqic
# simple_LR-g2-s0-d0-llf
# simple_LR-g2-s0-d0-rsq
# simple_LR-g2-s0-d0-rsq_adj
# simple_LR-g2-s0-d0-sigma2
# simple_LR-g3-s0-d0-aic
# simple_LR-g3-s0-d0-bic
# simple_LR-g3-s0-d0-f_pvalue
# simple_LR-g3-s0-d0-f_stat
# simple_LR-g3-s0-d0-hqic
# simple_LR-g3-s0-d0-llf
# simple_LR-g3-s0-d0-rsq
# simple_LR-g3-s0-d0-rsq_adj
# simple_LR-g3-s0-d0-sigma2
# simple_LR-g4-s0-d0-aic
# simple_LR-g4-s0-d0-bic
# simple_LR-g4-s0-d0-f_pvalue
# simple_LR-g4-s0-d0-f_stat
# simple_LR-g4-s0-d0-hqic
# simple_LR-g4-s0-d0-llf
# simple_LR-g4-s0-d0-rsq
# simple_LR-g4-s0-d0-rsq_adj
# simple_LR-g4-s0-d0-sigma2
# simple_LR-g5-s0-d0-aic
# simple_LR-g5-s0-d0-bic
# simple_LR-g5-s0-d0-f_pvalue
# simple_LR-g5-s0-d0-f_stat
# simple_LR-g5-s0-d0-hqic
# simple_LR-g5-s0-d0-llf
# simple_LR-g5-s0-d0-rsq
# simple_LR-g5-s0-d0-rsq_adj
# simple_LR-g5-s0-d0-sigma2
# simple_LR-g6-s0-d0-aic
# simple_LR-g6-s0-d0-bic
# simple_LR-g6-s0-d0-f_pvalue
# simple_LR-g6-s0-d0-f_stat
# simple_LR-g6-s0-d0-hqic
# simple_LR-g6-s0-d0-llf
# simple_LR-g6-s0-d0-rsq
# simple_LR-g6-s0-d0-rsq_adj
# simple_LR-g6-s0-d0-sigma2
# simple_LR-g7-s0-d0-aic
# simple_LR-g7-s0-d0-bic
# simple_LR-g7-s0-d0-f_pvalue
# simple_LR-g7-s0-d0-f_stat
# simple_LR-g7-s0-d0-hqic
# simple_LR-g7-s0-d0-llf
# simple_LR-g7-s0-d0-rsq
# simple_LR-g7-s0-d0-rsq_adj
# simple_LR-g7-s0-d0-sigma2
# source_file
# time_window
# unit_index
# z_score

# %%
# Combined runner for polar / diagonal plots across models and regions
# All comments are in English.

from itertools import product
from typing import Dict, List, Iterable, Tuple, Any, Optional, Union

from ephys_behavior_visualization import (
    plot_angle_fraction_polar,
    plot_diagonal_significance,
)

RegionSpec = Union[str, Iterable[str]]

def _ensure_list(x) -> List:
    if x is None:
        return []
    if isinstance(x, (list, tuple, set)):
        return list(x)
    return [x]

def _normalize_region_specs(regions: Iterable[RegionSpec]) -> List[Tuple[RegionSpec, str]]:
    """
    Convert user-provided region specs (strings or iterables of strings) into a list of
    (region_arg, label) pairs.

    - For a single string r: region_arg=r, label=r or 'ALL' if r==''.
    - For an iterable of strings G: region_arg=list(G), label='MD+RE' (joined with '+').
      If the downstream function does not accept lists, we'll fallback to a regex OR string 'MD|RE'.
    """
    out: List[Tuple[RegionSpec, str]] = []
    for spec in _ensure_list(regions):
        if isinstance(spec, str):
            label = spec if spec != "" else "ALL"
            out.append((spec, label))
        elif isinstance(spec, (list, tuple, set)):
            group = [str(s) for s in spec]
            label = "+".join(group) if group else "EMPTY_GROUP"
            out.append((group, label))
        else:
            raise TypeError(f"Unsupported region spec type: {type(spec)}. "
                            f"Use a string or an iterable of strings.")
    return out

def get_model_config() -> Dict[str, Dict[str, str]]:
    """
    Returns a dict mapping model keys to the columns used for x/y and p-values.
    Keys are chosen to be explicit about the comparison.
    """
    return {

        # Q-learning: Reward vs SumQ (g1)
        "qlearn_reward_vs_sumQ_g1": {
            "col_x": "simple_LR-QLearning_L2F1_softmax-reward-g1-s0-d0-coef",
            "col_y": "simple_LR-QLearning_L2F1_softmax-sumQ-1-g1-s0-d0-coef",
            "col_pval_x": "simple_LR-QLearning_L2F1_softmax-reward-g1-s0-d0-pval",
            "col_pval_y": "simple_LR-QLearning_L2F1_softmax-sumQ-1-g1-s0-d0-pval",
        },
        # Q-learning: Reward vs ChosenQ (g0)
        "qlearn_reward_vs_chosenQ_g0": {
            "col_x": "simple_LR-QLearning_L2F1_softmax-reward-g0-s0-d0-coef",
            "col_y": "simple_LR-QLearning_L2F1_softmax-chosenQ-g0-s0-d0-coef",
            "col_pval_x": "simple_LR-QLearning_L2F1_softmax-reward-g0-s0-d0-pval",
            "col_pval_y": "simple_LR-QLearning_L2F1_softmax-chosenQ-g0-s0-d0-pval",
        },
        # Threshold model: Reward vs Value (g2)
        "threshold_reward_vs_value_g2": {
            "col_x": "simple_LR-ForagingCompareThreshold-reward-g2-s0-d0-coef",
            "col_y": "simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-coef",
            "col_pval_x": "simple_LR-ForagingCompareThreshold-reward-g2-s0-d0-pval",
            "col_pval_y": "simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-pval",
        },
        # sumQ coef
        "sumQ-coef":{
            "col_x": "simple_LR-QLearning_L1F1_CK1_softmax-sumQ-1-g0-s0-d0-coef",
            "col_y": "simple_LR-QLearning_L1F1_CK1_softmax-sumQ-1-g3-s0-d0-coef",
            "col_pval_x": "simple_LR-QLearning_L1F1_CK1_softmax-sumQ-1-g0-s0-d0-pval",
            "col_pval_y": "simple_LR-QLearning_L1F1_CK1_softmax-sumQ-1-g3-s0-d0-pval",
        },
        # sumQ tval
        "sumQ-tval":{
            "col_x": "simple_LR-QLearning_L1F1_CK1_softmax-sumQ-1-g0-s0-d0-tval",
            "col_y": "simple_LR-QLearning_L1F1_CK1_softmax-sumQ-1-g3-s0-d0-tval",
            "col_pval_x": "simple_LR-QLearning_L1F1_CK1_softmax-sumQ-1-g0-s0-d0-pval",
            "col_pval_y": "simple_LR-QLearning_L1F1_CK1_softmax-sumQ-1-g3-s0-d0-pval",
        },
        # deltaQ coef
        "deltaQ-coef":{
            "col_x": "simple_LR-QLearning_L1F1_CK1_softmax-deltaQ-1-g1-s0-d0-coef",
            "col_y": "simple_LR-QLearning_L1F1_CK1_softmax-deltaQ-1-g3-s0-d0-coef",
            "col_pval_x": "simple_LR-QLearning_L1F1_CK1_softmax-deltaQ-1-g1-s0-d0-pval",
            "col_pval_y": "simple_LR-QLearning_L1F1_CK1_softmax-deltaQ-1-g3-s0-d0-pval",
        },
        # deltaQ tval
        "deltaQ-tval":{
            "col_x": "simple_LR-QLearning_L1F1_CK1_softmax-deltaQ-1-g1-s0-d0-tval",
            "col_y": "simple_LR-QLearning_L1F1_CK1_softmax-deltaQ-1-g3-s0-d0-tval",
            "col_pval_x": "simple_LR-QLearning_L1F1_CK1_softmax-deltaQ-1-g1-s0-d0-pval",
            "col_pval_y": "simple_LR-QLearning_L1F1_CK1_softmax-deltaQ-1-g3-s0-d0-pval",
        },



    }

def run_model_plot(
    *,
    ds,
    plot_methods: Iterable[str] = ("polar", "diag"),
    models: Iterable[str] = ("qlearn_reward_vs_sumQ_g1", "qlearn_reward_vs_chosenQ_g0", "threshold_reward_vs_value_g2"),
    regions: Iterable[RegionSpec] = ("",),  # string or list-of-strings; "" means all regions
    time_window: str = "0.3_2",      # e.g. "0.3_2" or "0.3_2_-1_0" or "-1_0"
    include: str = "all",
    # Polar-specific options
    angle_bin_deg: int = 15,
    normalize: str = "selected",
    start_angle_deg: float = 0.0,
    show_reference_diagonals: bool = True,
    # Diagonal-specific options
    point_size: float = 1.0,
    fit_oval: bool = False,
) -> Dict[str, Dict[str, Dict[str, Tuple[Optional[Any], Optional[Any], Optional[Any]]]]]:
    """
    Runs selected plot(s) for each model x region(or region-group) combination.

    'regions' can be:
      - a single string (e.g., "SI")
      - a list of strings (e.g., ["MD", "RE"]) to form a group
      - a mix: ["SI", ["MD", "RE"], ""]  where "" means all regions

    Returns a nested dict:
      results[method][model_key][region_label] -> (fig, ax, tbl_or_None)
    """
    plot_methods = [m.lower() for m in _ensure_list(plot_methods)]
    models = _ensure_list(models)
    region_specs = _normalize_region_specs(regions)

    cfg = get_model_config()
    missing = [m for m in models if m not in cfg]
    if missing:
        raise ValueError(f"Unknown model key(s): {missing}. "
                         f"Available: {list(cfg.keys())}")

    results: Dict[str, Dict[str, Dict[str, Tuple[Optional[Any], Optional[Any], Optional[Any]]]]] = {}

    for method, model_key in product(plot_methods, models):
        if method not in results:
            results[method] = {}
        if model_key not in results[method]:
            results[method][model_key] = {}

        model_cols = cfg[model_key]

        for region_arg, region_label in region_specs:
            # Prefer passing list directly. If that raises a TypeError, fallback to regex OR.
            filter_region = region_arg
            if isinstance(region_arg, (list, tuple, set)):
                try:
                    # Try list directly first.
                    _ = region_arg  # no-op; clarity
                except Exception:
                    # Not really needed, but placeholder if you want a validation step.
                    pass

            if method == "polar":
                try:
                    fig, ax, tbl = plot_angle_fraction_polar(
                        ds=ds,
                        filter_region=filter_region,
                        time_window=time_window,
                        col_x=model_cols["col_x"],
                        col_y=model_cols["col_y"],
                        col_pval_x=model_cols["col_pval_x"],
                        col_pval_y=model_cols["col_pval_y"],
                        include=include,
                        angle_bin_deg=angle_bin_deg,
                        normalize=normalize,
                        start_angle_deg=start_angle_deg,
                        show_reference_diagonals=show_reference_diagonals,
                    )
                except TypeError:
                    # Fallback: convert list group to regex OR string
                    if isinstance(region_arg, (list, tuple, set)):
                        regex_or = "|".join(region_arg)
                        fig, ax, tbl = plot_angle_fraction_polar(
                            ds=ds,
                            filter_region=regex_or,
                            time_window=time_window,
                            col_x=model_cols["col_x"],
                            col_y=model_cols["col_y"],
                            col_pval_x=model_cols["col_pval_x"],
                            col_pval_y=model_cols["col_pval_y"],
                            include=include,
                            angle_bin_deg=angle_bin_deg,
                            normalize=normalize,
                            start_angle_deg=start_angle_deg,
                            show_reference_diagonals=show_reference_diagonals,
                        )
                    else:
                        raise
                results[method][model_key][region_label] = (fig, ax, tbl)

            elif method in ("diag", "diagonal", "diagonal_significance"):
                try:
                    out = plot_diagonal_significance(
                        ds=ds,
                        filter_region=filter_region,
                        time_window=time_window,
                        col_x=model_cols["col_x"],
                        col_y=model_cols["col_y"],
                        col_pval_x=model_cols["col_pval_x"],
                        col_pval_y=model_cols["col_pval_y"],
                        point_size=point_size,
                        fit_oval=fit_oval,
                    )
                except TypeError:
                    if isinstance(region_arg, (list, tuple, set)):
                        regex_or = "|".join(region_arg)
                        out = plot_diagonal_significance(
                            ds=ds,
                            filter_region=regex_or,
                            time_window=time_window,
                            col_x=model_cols["col_x"],
                            col_y=model_cols["col_y"],
                            col_pval_x=model_cols["col_pval_x"],
                            col_pval_y=model_cols["col_pval_y"],
                            point_size=point_size,
                            fit_oval=fit_oval,
                        )
                    else:
                        raise

                if isinstance(out, tuple) and len(out) >= 2:
                    fig, ax = out[:2]
                else:
                    fig = ax = None
                results[method][model_key][region_label] = (fig, ax, None)

            else:
                raise ValueError(f"Unknown plot method: {method}")

    return results

# -------------------------
# EXAMPLES
# -------------------------

# 1) Single regions + a grouped region + ALL:
# results = run_model_plot(
#     ds=ds,
#     plot_methods=["polar", "diag"],
#     models=["qlearn_reward_vs_sumQ_g1", "qlearn_reward_vs_chosenQ_g0", "threshold_reward_vs_value_g2"],
#     regions=["SI", ["MD", "RE"], ""],   # list of lists supported
#     time_window="0.3_2",
# )

# 2) Only grouped regions, diagonal only:
# results = run_model_plot(
#     ds=ds,
#     plot_methods="diag",
#     models="qlearn_reward_vs_chosenQ_g0",
#     regions=[["MD", "RE"], ["SI", "ACA"]],
#     time_window="0.3_2_-1_0",
# )

# %%
 results = run_model_plot(
     ds=ds,
     plot_methods=["polar", "diag"],
     models=["deltaQ-coef"],
     #regions=[["MD"],[ "PL5","PL6a","ILA5","ILA6a"],["SI","MA"] ],
     time_window="0.3_2",  # or "0.3_2_-1_0" or "-1_0"
     include="all",
     angle_bin_deg=15,
     normalize="selected",
     start_angle_deg=0,
     show_reference_diagonals=True,
     point_size=1,
     fit_oval=False,
 )

# %%
 results = run_model_plot(
     ds=ds,
     plot_methods=["polar", "diag"],
     models=["qlearn_reward_vs_sumQ_g1"],
     regions=[["MD"],[ "PL5","PL6a","ILA5","ILA6a"],["SI","MA"] ],
     time_window="0.3_2",  # or "0.3_2_-1_0" or "-1_0"
     include="all",
     angle_bin_deg=15,
     normalize="selected",
     start_angle_deg=0,
     show_reference_diagonals=True,
     point_size=1,
     fit_oval=False,
 )

# %%
import importlib
import ephys_behavior_visualization
importlib.reload(ephys_behavior_visualization)

from ephys_behavior_visualization import plot_stat_3d_by_ccf

fig, ax, table = plot_stat_3d_by_ccf(
    ds,
    column="simple_LR-QLearning_L2F1_softmax-reward-g1-s0-d0-tval",
    filter_region=["MD", "SI","MA","PL5","PL6a","ILA5","ILA6a","MOs2/3","MOs5","MOs6a"],           # or ["MD","PL"] or "!MD" or ""
    time_window="0.3_2",
    symmetric_color=True,
)

# %%
"simple_LR-QLearning_L2F1_softmax-reward-g1-s0-d0-tval"
"simple_LR-QLearning_L2F1_softmax-sumQ-1-g1-s0-d0-tval"

"simple_LR-QLearning_L2F1_softmax-chosenQ-g0-s0-d0-tval"

            "col_x": "simple_LR-QLearning_L2F1_softmax-reward-g0-s0-d0-coef",
            "col_y": "simple_LR-QLearning_L2F1_softmax-chosenQ-g0-s0-d0-coef",

# %%
save_dir
# Out:
# 'eps_figures'

# %%
import importlib
import ephys_behavior_visualization
importlib.reload(ephys_behavior_visualization)

from ephys_behavior_visualization import plot_stat_2d_grid_by_ccf, plot_unit_count_2d_grid_by_ccf,plot_stat_profile_along_axis_by_ccf,plot_significant_fraction_along_axis_by_ccf

import os
save_dir = "eps_figures"
os.makedirs(save_dir, exist_ok=True)

latent="simple_LR-QLearning_L2F1_softmax-reward-g0-s0-d0-tval"
latent_p="simple_LR-QLearning_L2F1_softmax-reward-g0-s0-d0-pval"

#latent="simple_LR-QLearning_L2F1_softmax-chosenQ-g0-s0-d0-tval"
#latent_p="simple_LR-QLearning_L2F1_softmax-chosenQ-g0-s0-d0-pval"


time_window="0.3_2"
#time_window="-1_0"
region=["MD"]
bin_size_um=50
repertoire_um=100

region_str = "_".join(region)
fname_prefix = f"{latent}_{region_str}_tw{time_window}_bin{bin_size_um}_rep{repertoire_um}"

# 200 µm grid but each neuron covers 400 µm neighborhood
fig, ax, _ = plot_stat_2d_grid_by_ccf(
    ds,
    column=latent,
    filter_region=region,
    time_window=time_window,
    plane="xz",
    bin_size_um=bin_size_um,
    repertoire_um=repertoire_um,   # each neuron influences a 400×400 µm area
    min_points_per_square=5,
   # vmin=-10,
   # vmax=10
   # flip_axis="z",
   # flip_mid_um=5700,
   # flip_side="greater",
)
fig.savefig(os.path.join(save_dir, f"{fname_prefix}_stat_2d_grid.eps"), format="eps", bbox_inches="tight")

# Matching count heatmap
fig2, ax2, _ = plot_unit_count_2d_grid_by_ccf(
    ds,
    filter_region=region,
    time_window=time_window,
    plane="xz",
    bin_size_um=bin_size_um,
    repertoire_um=repertoire_um,
   # flip_axis="z",
  #  flip_mid_um=5700,
  #  flip_side="greater",
    log_scale=False,
)
fig2.savefig(os.path.join(save_dir, f"{fname_prefix}_unit_count_2d_grid.eps"), format="eps", bbox_inches="tight")


# Average t-value vs Right–Left (Z) with 200 µm bins, Gaussian smoothing σ=400 µm
fig3, ax3, _ = plot_stat_profile_along_axis_by_ccf(
    ds,
    column=latent,
    filter_region=region,
    time_window=time_window,
    axis="x",
    bin_size_um=bin_size_um,
    repertoire_um=repertoire_um,       # each unit influences ±200 µm
    smooth="none",
    min_points_per_bin=30,
    smooth_um=50
)
fig3.savefig(os.path.join(save_dir, f"{fname_prefix}_stat_profile_x.eps"), format="eps", bbox_inches="tight")


fig4, ax4, _ = plot_significant_fraction_along_axis_by_ccf(
    ds,
    column=latent_p,          # p-value column
    effect_column=latent,
    filter_region=region,
    time_window=time_window,
    axis="x",
    bin_size_um=bin_size_um,
    repertoire_um=repertoire_um,
    smooth="none",
    min_points_per_bin=30,
    alpha_level=0.05,          # OK here
    which="all3"
    
)
fig4.savefig(os.path.join(save_dir, f"{fname_prefix}_sig_fraction_x.eps"), format="eps", bbox_inches="tight")

print(f"All figures saved to {save_dir}/")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# All figures saved to eps_figures/
