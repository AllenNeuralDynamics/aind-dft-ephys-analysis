# %%
# =============================================================================
# 1. ENVIRONMENT SETUP & MODULE IMPORTS
# =============================================================================
"""
Initialize the analysis environment by loading essential modules and setting up
the Python path to access custom analysis functions.
"""

# Enable automatic reloading of modules for interactive development
# %load_ext autoreload
# %autoreload 2

# Import essential system modules
import sys
from pathlib import Path

# Define the path to custom analysis modules
# Note: Update this path to match your local installation
MODULE_PATH = Path("/root/capsule/src/aind_dft_ephys_analysis")

# Add module path to system path for importing custom functions
if str(MODULE_PATH) not in sys.path:
    sys.path.insert(0, str(MODULE_PATH))

print(f"✅ Analysis modules loaded from: {MODULE_PATH}")
print("🔄 Auto-reload enabled for interactive development")
# Out:
# ✅ Analysis modules loaded from: /root/capsule/src/aind_dft_ephys_analysis
# 🔄 Auto-reload enabled for interactive development

# %%
import matplotlib.pyplot as plt
from ophys_behavior import OphysBehavior
from general_utils import find_ephys_sessions, find_behavior_sessions, extract_session_name_core

# %%
find_behavior_sessions()
# Out:
# (['behavior_752703_2024-11-20_13-01-14_processed_2026-04-27_17-22-37_3',
#   'behavior_752703_2024-11-20_13-01-14_processed_2026-04-27_17-22-37_1',
#   'behavior_752703_2024-11-20_13-01-14_processed_2026-04-27_17-22-37',
#   'behavior_752703_2024-11-20_13-01-14_processed_2026-04-27_17-22-37_2',
#   'behavior_762206_2025-01-17_16-20-02_processed_2025-01-18_07-17-12',
#   'behavior_762206_2025-01-18_17-48-17_processed_2025-01-19_06-46-32',
#   'behavior_762283_2025-01-09_17-36-00_processed_2025-01-10_09-53-40',
#   'behavior_769037_2025-02-11_17-01-10_processed_2025-02-13_05-33-07',
#   'behavior_769037_2025-02-13_16-54-02_processed_2025-02-14_05-05-43',
#   'behavior_769037_2025-02-18_17-56-48_processed_2025-02-19_05-27-47',
#   'behavior_769037_2025-02-20_16-34-59_processed_2025-02-21_05-26-11',
#   'behavior_769037_2025-02-21_16-39-56_processed_2025-02-22_05-37-25',
#   'behavior_769037_2025-02-24_16-43-38_processed_2025-02-25_05-26-08',
# ...

# %%
 'behavior_777403_2025-04-02_16-36-15_processed_2025-04-03_05-18-50',
  'behavior_777403_2025-04-02_16-36-15_processed_2025-12-04_18-53-24',
  'behavior_777403_2025-04-03_16-31-12_processed_2026-04-11_01-11-19',
  'behavior_777403_2025-04-03_16-31-12_processed_2025-04-04_05-44-16',
  'behavior_777403_2025-04-07_16-28-26_processed_2025-04-09_19-44-46',
  'behavior_777403_2025-04-07_16-28-26_processed_2025-12-10_08-16-09',
  'behavior_777403_2025-04-07_16-28-26_processed_2025-04-08_17-13-28',
  'behavior_777403_2025-04-08_16-40-47_processed_2025-12-10_17-30-49',
  'behavior_777403_2025-04-08_16-40-47_processed_2025-04-09_05-12-19',
  'behavior_777403_2025-04-08_16-40-47_processed_2025-12-10_18-06-07',
  'behavior_777403_2025-04-09_16-41-57_processed_2025-12-10_18-14-12',
  'behavior_777403_2025-04-09_16-41-57_processed_2025-04-10_05-12-59',
  'behavior_777403_2025-04-11_16-53-47_processed_2025-12-10_07-18-12',
# Found ophys NWB: /root/capsule/data/behavior_777407_2025-04-02_16-57-03_processed_2025-12-04_11-52-40/nwb/behavior_777407_2025-04-02_16-57-03.nwb
# /opt/conda/lib/python3.10/site-packages/hdmf/spec/namespace.py:620: UserWarning: Ignoring the following cached namespace(s) because another version is already loaded:
# core - cached version: 2.9.0, loaded version: 2.7.0
# The loaded extension(s) may not be compatible with the cached extension(s) in the file. Please check the extension documentation and ignore this warning if these versions are compatible.
#   self.warn_for_ignored_namespaces(ignored_namespaces)
# Successfully read ophys NWB from: /root/capsule/data/behavior_777407_2025-04-02_16-57-03_processed_2025-12-04_11-52-40/nwb/behavior_777407_2025-04-02_16-57-03.nwb
# [Attempt 1/3] Network failure for session behavior_777407_2025-04-02_16-57-03_processed_2025-12-04_11-52-40: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ...

# %%
session_list=[
'behavior_773352_2025-02-25_16-34-05_processed_2025-02-26_05-54-36',
'behavior_773352_2025-02-26_16-25-42_processed_2025-02-27_06-35-55',
'behavior_773352_2025-03-03_16-49-53_processed_2025-03-04_05-59-53'
]


OpBe=OphysBehavior.empty()

OpBe.extract_aligned_matrix_and_latent_data(time_window=[-3, 6], 
                                               bin_size=0.05,
                                               behavior_model='ForagingCompareThreshold', 
                                               latent_name=['value','value-1'], 
                                               data_name=['G_1_preprocessed-bright','G_2_preprocessed-bright'],
                                               session_name_list=session_list,
                                               latent_normalization='rank')
# Out:
# Found ophys NWB: /root/capsule/data/behavior_773352_2025-02-06_11-11-31_processed_2025-02-07_05-35-35/nwb/behavior_773352_2025-02-06_11-11-31.nwb
# Successfully read ophys NWB from: /root/capsule/data/behavior_773352_2025-02-06_11-11-31_processed_2025-02-07_05-35-35/nwb/behavior_773352_2025-02-06_11-11-31.nwb
# Found ophys NWB: /root/capsule/data/behavior_773352_2025-02-25_16-34-05_processed_2025-02-26_05-54-36/nwb/behavior_773352_2025-02-25_16-34-05.nwb
# Successfully read ophys NWB from: /root/capsule/data/behavior_773352_2025-02-25_16-34-05_processed_2025-02-26_05-54-36/nwb/behavior_773352_2025-02-25_16-34-05.nwb
# Found ophys NWB: /root/capsule/data/behavior_773352_2025-02-26_16-25-42_processed_2025-02-27_06-35-55/nwb/behavior_773352_2025-02-26_16-25-42.nwb
# Successfully read ophys NWB from: /root/capsule/data/behavior_773352_2025-02-26_16-25-42_processed_2025-02-27_06-35-55/nwb/behavior_773352_2025-02-26_16-25-42.nwb
# ...

# %%
session_list=[
'behavior_773352_2025-02-25_16-34-05_processed_2025-02-26_05-54-36',
'behavior_773352_2025-02-26_16-25-42_processed_2025-02-27_06-35-55',
'behavior_773352_2025-03-03_16-49-53_processed_2025-03-04_05-59-53'
]


OpBe=OphysBehavior.empty()

OpBe.extract_aligned_matrix_and_latent_data(time_window=[-3, 6], 
                                               bin_size=0.05,
                                               behavior_model='q_learning_Y1', 
                                               latent_name=['RPE','deltaQ-1','sumQ-1'], 
                                               data_name=['G_1_preprocessed-bright','G_2_preprocessed-bright'],
                                               session_name_list=session_list,
                                               latent_normalization='rank')
# Out:
# Found: Ophys NWB file found in the folder '/root/capsule/data/behavior_773352_2025-02-06_11-11-31_processed_2025-02-07_05-35-35/nwb' with the pattern '*.nwb'.
# Found: Ophys NWB file found in the folder '/root/capsule/data/behavior_773352_2025-02-25_16-34-05_processed_2025-02-26_05-54-36/nwb' with the pattern '*.nwb'.
# Fitted parameters:
#   alpha_pos: 0.44655026498683714
#   alpha_neg: 0.04053318168770467
#   zeta: 0.0
#   beta: 4.224504910197645
#   bias: 0.3940609129158708
# The response returned an empty list. No data was found.
# No entries for alias 'q_learning_Y1' in fit results
# Skipping session '773352_2025-02-25_16-34-05' for latent combination (behavior_model=q_learning_Y1, latent_name=RPE) due to trial count mismatch.
# No entries for alias 'q_learning_Y1' in fit results
# Skipping session '773352_2025-02-25_16-34-05' for latent combination (behavior_model=q_learning_Y1, latent_name=deltaQ-1) due to trial count mismatch.
# ...

# %%
aligned_copy = OpBe.combined_aligned_matrix['G_1_dff-bright'].copy()
latent_copy = OpBe.combined_latent_data['ForagingCompareThreshold']['value-1'].copy()

OpBe.plot_quantiles(latent_name='value-1',
                    z_score=False,
                    quantiles_num=8,
                    time_window=[OpBe.combined_params['time_window'][0],OpBe.combined_params['time_window'][1]],
                    aligned_matrix=aligned_copy,
                    latent_data=latent_copy,
                    colorbar_cmap='inferno',
                    title_font_size=20,
                    label_font_size=16,
                    baseline_window=None,
                    min_trials_each_quantil=200

                    )

# %%
import numpy as np
aligned_copy = OpBe.combined_aligned_matrix['G_1_dff-bright'].copy()
latent_copy = OpBe.combined_latent_data['ForagingCompareThreshold']['value-1'].copy()

OpBe.plot_latent_firing_rate(
    time_window=[-2,0],
    num_bins=20,
    z_score=False,
    latent_name='value',
    aligned_matrix=aligned_copy,
    latent_data=latent_copy,
    aligned_matrix_timestampes=np.arange(
        OpBe.combined_params['time_window'][0],
        OpBe.combined_params['time_window'][1],
        OpBe.combined_params['bin_size']
    ),
    baseline_window=None,
    x_range=[-0.1,1],
    y_range=[0.3,0.8]
)
# Out:
# /opt/conda/lib/python3.10/site-packages/numpy/_core/_methods.py:223: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/conda/lib/python3.10/site-packages/numpy/_core/_methods.py:215: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
aligned_copy = OpBe.combined_aligned_matrix['G_1_preprocessed-bright'].copy()
latent_copy = OpBe.combined_latent_data['q_learning_Y1']['RPE'].copy()

OpBe.plot_quantiles(latent_name='RPE',
                    z_score=False,
                    quantiles_num=10,
                    time_window=[OpBe.combined_params['time_window'][0],OpBe.combined_params['time_window'][1]],
                    aligned_matrix=aligned_copy,
                    latent_data=latent_copy,
                    colorbar_cmap='inferno',
                    title_font_size=20,
                    label_font_size=16,
                    baseline_window=None

                    )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /root/capsule/notebook/ophys_behavior_playground.ipynb Cell 9 line 2
#       <a href='vscode-notebook-cell://codeocean.allenneuraldynamics.org/root/capsule/notebook/ophys_behavior_playground.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> aligned_copy = OpBe.combined_aligned_matrix['G_1_preprocessed-bright'].copy()
# ----> <a href='vscode-notebook-cell://codeocean.allenneuraldynamics.org/root/capsule/notebook/ophys_behavior_playground.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> latent_copy = OpBe.combined_latent_data['q_learning_Y1']['RPE'].copy()
#       <a href='vscode-notebook-cell://codeocean.allenneuraldynamics.org/root/capsule/notebook/ophys_behavior_playground.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> OpBe.plot_quantiles(latent_name='RPE',
# ...

# %%
import numpy as np

aligned_copy = OpBe.combined_aligned_matrix['G_1_preprocessed-bright'].copy()
latent_copy = OpBe.combined_latent_data['q_learning_Y1']['RPE'].copy()

OpBe.plot_latent_firing_rate(
    time_window=[0,3],
    num_bins=20,
    z_score=False,
    latent_name='RPE',
    aligned_matrix=aligned_copy,
    latent_data=latent_copy,
    aligned_matrix_timestampes=np.arange(
        OpBe.combined_params['time_window'][0],
        OpBe.combined_params['time_window'][1],
        OpBe.combined_params['bin_size']
    ),
    baseline_window=None
)

# %%
session_name ='behavior_773352_2025-02-26_16-25-42_processed_2025-02-27_06-35-55'

session_name ='behavior_773352_2025-02-25_16-34-05_processed_2025-02-26_05-54-36'
#session_name ='behavior_773352_2025-02-26_16-25-42_processed_2025-02-27_06-35-55'
#session_name ='behavior_773352_2025-03-03_16-49-53_processed_2025-03-04_05-59-53'


OpBe=OphysBehavior(session_name=session_name)
# Out:
# Found: Ophys NWB file found in the folder '/root/capsule/data/behavior_773352_2025-02-25_16-34-05_processed_2025-02-26_05-54-36/nwb' with the pattern '*.nwb'.

# %%
OpBe.plot_heat_map(event_name=['go_cue'],data_name= ['G_1_preprocessed-bright'],behavior_model='ForagingCompareThreshold',align_by_latent_name='value-1',value_range=[0.05,1.5])
OpBe.plot_psth(event_name=['reward_go_cue_start','no_reward_go_cue_start'],data_name=['G_1_preprocessed-bright','G_2_preprocessed-bright'])
# Out:
# Aligned data not found for G_1_preprocessed-bright and event go_cue. Computing alignment...
# Aligned data not found for G_1_preprocessed-bright and event reward_go_cue_start. Computing alignment...
# Aligned data not found for G_1_preprocessed-bright and event no_reward_go_cue_start. Computing alignment...
# Aligned data not found for G_2_preprocessed-bright and event reward_go_cue_start. Computing alignment...
# Aligned data not found for G_2_preprocessed-bright and event no_reward_go_cue_start. Computing alignment...

# %%
OpBe.plot_licks_raster_and_psth(offset=0,time_window=[-3,6],bin_size=0.05,plot_combine=False, event_names= ['go_cue'],align_by_latent_name='total_value',behavior_model='q_learning_Y1')
# Out:
# Fitted parameters:
#   alpha_pos: 0.44655026498683714
#   alpha_neg: 0.04053318168770467
#   zeta: 0.0
#   beta: 4.224504910197645
#   bias: 0.3940609129158708
# The response returned an empty list. No data was found.

# %%
session_name='behavior_770528_2025-02-10_17-16-38_processed_2025-02-11_07-11-00'
session_name='behavior_770528_2025-02-13_16-54-06_processed_2025-02-14_05-26-45'
session_name='behavior_770528_2025-02-17_18-28-01_processed_2025-02-18_05-32-04'
session_name='behavior_770528_2025-02-18_17-52-56_processed_2025-02-19_05-08-20'
session_name='behavior_770528_2025-02-20_16-32-44_processed_2025-02-23_13-22-47'
session_name='behavior_770528_2025-02-21_16-39-58_processed_2025-02-22_05-19-23'
OpBe.fit_q_learning_model()
OpBe.fit_choice_logistic_regression()
OpBe.fitted_model_names
OpBe.plot_behavior_session(model_name='q_learning_Y1',include_fitted_data=True)
OpBe.plot_licks_raster_and_psth(offset=0,time_window=[-2,4],bin_size=0.05,plot_combine=False, event_names= ['reward_go_cue_start', 
                                                        'no_reward_go_cue_start'])
OpBe.plot_quantiles(latent_name='RPE',
                    behavior_model='QLearning_L2F1_softmax',
                    z_score=False,
                    quantiles_num=5,
                    data_name= 'G_0_dff-bright',
                    time_window=[-3,6],
                    )
OpBe.plot_quantiles(latent_name='RPE',
                    z_score=False,
                    quantiles_num=5,
                    data_name= 'G_1_dff-bright',
                    time_window=[-3,6],
                    behavior_model='QLearning_L2F1_softmax'
                    )
OpBe.plot_quantiles(latent_name='sumQ',
                    behavior_model='QLearning_L2F1_softmax',
                    z_score=False,
                    quantiles_num=5,
                    data_name= 'G_0_dff-bright',
                    time_window=[-3,6],
                    )
OpBe.plot_quantiles(latent_name='sumQ',
                    z_score=False,
                    quantiles_num=5,
                    data_name= 'G_1_dff-bright',
                    time_window=[-3,6],
                    behavior_model='QLearning_L2F1_softmax'
                    )
OpBe.plot_quantiles(latent_name='deltaQ',
                    behavior_model='QLearning_L2F1_softmax',
                    z_score=False,
                    quantiles_num=5,
                    data_name= 'G_0_dff-bright',
                    time_window=[-3,6],
                    )
OpBe.plot_quantiles(latent_name='deltaQ',
                    z_score=False,
                    quantiles_num=5,
                    data_name= 'G_1_dff-bright',
                    time_window=[-3,6],
                    behavior_model='QLearning_L2F1_softmax'
                    )

OpBe.plot_heat_map(event_name=['reward_go_cue_start','no_reward_go_cue_start'],data_name= ['Iso_0_dff-bright','Iso_1_dff-bright'])
OpBe.plot_psth(event_name=['reward_go_cue_start','no_reward_go_cue_start'],data_name=['Iso_0_dff-bright','Iso_1_dff-bright'])
# Out:
# Found: Ophys NWB file found in the folder '/root/capsule/data/behavior_793726_2025-07-24_16-22-47_processed_2025-07-25_15-21-34/nwb' with the pattern '*.nwb'.
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# File ~/capsule/src/phys_behavior/shared.py:685, in Shared.read_ophys_nwb(self, nwb_full_path, session_name)
#     683 try:
#     684     # Try reading the file with NWBHDF5IO.
# --> 685     io = NWBHDF5IO(file_path, "r")
#     686     nwb_ophys_data = io.read()
#
# File /opt/conda/lib/python3.10/site-packages/hdmf/utils.py:578, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     577 pargs = _check_args(args, kwargs)
# --> 578 return func(args[0], **pargs)
#
# File /opt/conda/lib/python3.10/site-packages/pynwb/__init__.py:406, in NWBHDF5IO.__init__(self, **kwargs)
#     405 tm = get_type_map()
# ...

# %%
OpBe.plot_example_trace_two_channel(data_x_name='G_0_dff-bright',data_y_name='G_1_dff-bright')

# %%
session_name = "769038_2025-02-12_12-48-11"

OpBe=OphysBehavior(session_name=session_name)
OpBe.fit_q_learning_model()
OpBe.plot_behavior_session(include_fitted_data=True,model_name='q_learning_Y1')

# %%
  'behavior_773352_2025-01-24_11-57-43_processed_2025-02-22_18-57-16_1',
  'behavior_773352_2025-01-24_11-57-43_processed_2025-02-22_18-57-16',
  'behavior_773352_2025-01-27_11-22-34_processed_2025-01-28_05-08-25',
  'behavior_773352_2025-01-30_11-34-24_processed_2025-02-22_19-28-07',
  'behavior_773352_2025-01-30_11-34-24_processed_2025-02-23_12-40-17',
  'behavior_773352_2025-01-31_11-17-08_processed_2025-02-01_08-23-19',
  'behavior_773352_2025-02-04_12-08-19_processed_2025-02-05_05-45-33',
  'behavior_773352_2025-02-05_11-14-04_processed_2025-02-06_05-32-03',
  'behavior_773352_2025-02-06_11-11-31_processed_2025-02-07_05-35-35',
  'behavior_773352_2025-02-14_11-11-00_processed_2025-02-15_05-27-16',
  'behavior_773352_2025-02-17_11-10-44_processed_2025-02-18_05-07-41',
  'behavior_773352_2025-02-18_12-22-14_processed_2025-02-19_05-11-57',
  'behavior_773352_2025-02-19_11-19-37_processed_2025-02-20_05-23-36',
  'behavior_773352_2025-02-20_11-30-20_processed_2025-02-21_05-16-16',
  'behavior_773352_2025-02-21_11-12-55_processed_2025-02-22_05-30-04',
  'behavior_773352_2025-02-24_16-48-02_processed_2025-02-25_05-38-41',
  'behavior_773352_2025-02-25_16-34-05_processed_2025-02-26_05-54-36',
  'behavior_773352_2025-02-26_16-25-42_processed_2025-02-27_06-35-55'])

# %%
OpBe.fitted_latent

# %%
import matplotlib.pyplot as plt
from ophys_behavior import OphysBehavior
from utils import find_ephys_sessions, find_behavior_sessions, extract_key_str

session_name = "773352_2025-02-06_11-11-31"
#session_name = "773352_2025-02-21_11-12-55"
session_name = "773352_2025-02-26_16-25-42"

OpBe=OphysBehavior(session_name=session_name)
#OpBe.fit_choice_logistic_regression()
OpBe.fit_choice_logistic_regression(folder_with_nwb='/root/capsule/data/behavior_nwb')
OpBe.visualize_choice_logistic_regression()
# Out:
# Found: Ophys NWB file found in the folder '/root/capsule/data/behavior_773352_2025-02-26_16-25-42_processed_2025-02-27_06-35-55/nwb' with the pattern '*.nwb'.
# Reading NWB: /root/capsule/data/behavior_nwb/753124_2024-12-10_17-24-56.nwb
# /opt/conda/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'core' version 2.6.0-alpha because version 2.7.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# Reading NWB: /root/capsule/data/behavior_nwb/753125_2024-10-09_10-50-19.nwb
# /opt/conda/lib/python3.10/site-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.5.1 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# ...

# %%
OpBe.fitted_model_names

# %%
OpBe.plot_behavior_session(include_fitted_data=True,model_name='logistic_regression')

# %%
OpBe.visualize_choice_logistic_regression()

# %%
OpBe.plot_correlation_two_channel()

# %%
OpBe.plot_example_trace_two_channel()

# %%
OpBe.plot_latent_firing_rate(time_window=[0.7,2],latent_name='RPE', behavior_model='q_learning_Y1',data_name='G_1_preprocessed-bright')
