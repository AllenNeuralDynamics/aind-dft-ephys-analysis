# %%
from nwb_utils import NWBUtils

# Example ephys session
ephys_path = "/root/capsule/data/" \
             "ecephys_776293_2025-02-14_15-19-17_sorted_2025-02-28_21-37-07/" \
             "nwb/" \
             "ecephys_776293_2025-02-14_15-19-17_experiment1_recording1.nwb"

# Example behavior/ophys session
ophys_path = "/root/capsule/data/" \
             "behavior_777403_2025-04-11_16-53-47_processed_2025-04-12_04-37-54/" \
             "nwb/" \
             "behavior_777403_2025-04-11_16-53-47.nwb"

# Read ephys
ephys_data = NWBUtils.read_ephys_nwb(nwb_full_path=ephys_path)
# ephys_data will be None on failure, or the NWBFile-like object on success.

# Read ophys/behavior
ophys_data = NWBUtils.read_ophys_nwb(nwb_full_path=ophys_path)
# ophys_data will likewise be None on failure, or the NWBFile-like object on success.

# %%
from nwb_utils import NWBUtils

ephys_data = NWBUtils.read_ephys_nwb(
    session_name="776293_2025-02-14_15-19-17"
)

ophys_data = NWBUtils.read_ophys_nwb(
    session_name="777403_2025-04-11_16-53-47"
)

# %%
from general_utils import find_ephys_sessions, find_behavior_sessions
from nwb_utils import NWBUtils

def main():
    data_root = '/root/capsule/data/'

    # 1. Find all ephys sessions
    all_ephys, ephys_by_animal, spike_sorted = find_ephys_sessions(data_root)
    print("All ephys sessions:", all_ephys)
    print("Spike-sorted sessions:", spike_sorted)

    # 2. Find all behavior sessions
    all_behav, behav_by_animal, processed_behav = find_behavior_sessions(data_root)
    print("All behavior sessions:", all_behav)
    print("Processed behavior sessions:", processed_behav)

    # 3. Read the first spike-sorted ephys session
    if spike_sorted:
        first_ephys = spike_sorted[0]
        print(f"\nLoading ephys session: {first_ephys}")
        ephys_data = NWBUtils.read_ephys_nwb(
            session_name=first_ephys,
            folder_path=data_root
        )
        # ephys_data is None on failure, or the NWBFile-like object on success

    # 4. Read the first processed behavior session
    if processed_behav:
        first_behav = processed_behav[0]
        print(f"\nLoading behavior session: {first_behav}")
        behav_data = NWBUtils.read_ophys_nwb(
            session_name=first_behav,
            folder_path=data_root
        )
        # behav_data is None on failure, or the NWBFile-like object on success

if __name__ == "__main__":
    main()

# %%
from behavior_utils import extract_event_timestamps
from nwb_utils import NWBUtils
behav_data = NWBUtils.read_ophys_nwb(session_name='behavior_762206_2025-01-17_16-20-02_processed_2025-01-18_07-17-12')
behav_data = NWBUtils.read_behavior_nwb(session_name='ecephys_753125_2024-10-14_15-37-15_sorted_2024-11-09_20-07-38')
extract_event_timestamps(behav_data,'left_lick')

# %%
from ephys_behavior_visualization import plot_raster_graph
from nwb_utils import NWBUtils
from behavior_utils import extract_fitted_data, find_trials,get_fitted_model_names


session_name='ecephys_776293_2025-02-18_12-51-36_sorted_2025-03-30_05-50-33'
session_name='764790_2024-12-19_16-11-34_sorted_2025-02-21_14-46-33'
#session_name='764790_2024-12-19_16-11-34'
print(get_fitted_model_names(session_name=session_name))

nwb_data,tag=NWBUtils.combine_nwb(session_name=session_name)
fitted_data=extract_fitted_data(nwb_behavior_data=nwb_data,session_name=session_name,model_alias='QLearning_L1F1_CK1_softmax',latent_name='deltaQ')
exclude_trials=find_trials(nwb_behavior_data=nwb_data,trial_type='no_response')

plot_raster_graph(nwb_data=nwb_data,unit_index=100,fitted_data=fitted_data,exclude_trials=exclude_trials,latent_name='deltaQ')
plot_raster_graph(nwb_data=nwb_data,unit_index=100,align_to_event='left_lick',save_figure=True,figure_name_prefix='764790_2024-12-19_16-11-34',save_format='pdf')

nwb_data.io.close()

# %%
from ephys_behavior import plot_raster_graph
from nwb_utils import NWBUtils
from behavior_utils import extract_fitted_data, find_trials,get_fitted_model_names,generate_behavior_summary


session_name='ecephys_776293_2025-02-18_12-51-36_sorted_2025-03-30_05-50-33'
session_name='764790_2024-12-19_16-11-34_sorted_2025-02-21_14-46-33'
#session_name='764790_2024-12-19_16-11-34'
print(get_fitted_model_names(session_name=session_name))

nwb_data,tag=NWBUtils.combine_nwb(session_name=session_name)
fitted_data=extract_fitted_data(nwb_behavior_data=nwb_data,session_name=session_name,model_alias='QLearning_L1F1_CK1_softmax',latent_name='deltaQ')
exclude_trials=find_trials(nwb_behavior_data=nwb_data,trial_type=['no_response','no_response'])


summary=generate_behavior_summary(nwb_data)

nwb_data.io.close()

# %%
from ephys_behavior import plot_raster_graph,get_units_passed_default_qc
from nwb_utils import NWBUtils
from behavior_utils import extract_fitted_data, find_trials,get_fitted_model_names


session_name='ecephys_776293_2025-02-18_12-51-36_sorted_2025-03-30_05-50-33'
session_name='764790_2024-12-19_16-11-34_sorted_2025-02-21_14-46-33'
#session_name='764790_2024-12-19_16-11-34'
print(get_fitted_model_names(session_name=session_name))

ephys_nwb=NWBUtils.read_ephys_nwb(session_name=session_name)
units_passing_qc=get_units_passed_default_qc(ephys_nwb)

ephys_nwb.io.close()

# %%
from general_utils import find_behavior_sessions, find_ephys_sessions

_,_,spike_sorted_sessions=find_ephys_sessions()
print(spike_sorted_sessions)

# %%
from behavior_utils import generate_behavior_summary_combined


df_combined_behavior_summary=generate_behavior_summary_combined(session_names=['ecephys_764769_2024-12-11_18-21-49_sorted_2024-12-13_10-04-48','764790_2024-12-19_16-11-34_sorted_2025-02-21_14-46-33'],save_result=True)

# %%
from ephys_behavior import plot_raster_graph,get_the_mean_firing_rate,get_the_mean_firing_rate_combined
from nwb_utils import NWBUtils
from behavior_utils import extract_fitted_data, find_trials,get_fitted_model_names

#df=get_the_mean_firing_rate(nwb_data=nwb_data,time_windows=[[-1,0],[0,2]],z_score=[True,False])
df_combined_firing_rates=get_the_mean_firing_rate_combined(session_names=['ecephys_764769_2024-12-11_18-21-49_sorted_2024-12-13_10-04-48','764790_2024-12-19_16-11-34_sorted_2025-02-21_14-46-33'],save_result=True)

# %%
from general_utils import smart_read_csv

fn_rates  = '/root/capsule/results/combined_firing_rates.csv'
fn_behav  = '/root/capsule/results/combined_behavior_summary.csv'


# Now load both tables, and they'll come back with real lists & dicts
df_combined_firing_rates    = smart_read_csv(fn_rates)
df_combined_behavior_summary = smart_read_csv(fn_behav)

# %%
from ephys_behavior import correlate_firing_latent
import pandas as pd

models   = ['simple_LR','ARMA_model','ARDL_model','cyclic_shift','linear_shift','phase_randomization']
variables = [
    'QLearning_L1F1_CK1_softmax_deltaQ',
    # …
    'QLearning_L2F1_CK1_softmax_RPE',
]
# Now call your function
df_with_dicts = correlate_firing_latent(
    df_combined_firing_rates,
    df_combined_behavior_summary,
    variables=variables,
    correlation_model=models,
    save_result=True
)

# %%
from collections import defaultdict
from behavior_utils import get_fitted_model_names
from general_utils import find_ephys_sessions

# Find all spike-sorted sessions
_, _, spike_sorted_sessions = find_ephys_sessions()

model_to_sessions = defaultdict(list)
session_to_models = {}

for current_session in spike_sorted_sessions:
    model_names = get_fitted_model_names(current_session)
    
    # Skip sessions with no fitted models
    if not model_names:
        print(f"⚠️ No models found for session: {current_session}")
        continue
    
    session_to_models[current_session] = model_names
    
    # Add session under each model name
    for model in model_names:
        model_to_sessions[model].append(current_session)

# Summary
total_unique_models = len(model_to_sessions)
print(f"\n✅ Total unique models: {total_unique_models}\n")

print("Number of sessions with each model:")
for model, sessions in sorted(model_to_sessions.items(), key=lambda x: len(x[1]), reverse=True):
    print(f"{model}: {len(sessions)} sessions")

print(f"\n✅ Total sessions with at least one fitted model: {len(session_to_models)} / {len(spike_sorted_sessions)}")

# %%
from behavior_utils import generate_behavior_summary_combined
from general_utils import find_ephys_sessions
from general_utils import smart_read_csv
import pandas as pd
from ephys_behavior import (
    get_the_mean_firing_rate_combined,   # ← updated name here
    correlate_firing_latent_multiple_variable
)
import os

# 1) find your sorted sessions
_, _, spike_sorted_sessions = find_ephys_sessions()
print("Sessions to process:", spike_sorted_sessions)


variables = [
["QLearning_L2F1_softmax-reward","QLearning_L2F1_softmax-chosenQ-1"],
[ "QLearning_L2F1_softmax-reward","QLearning_L2F1_softmax-sumQ-1"],
["ForagingCompareThreshold-reward","ForagingCompareThreshold-value-1"],
["QLearning_L2F1_softmax-reward"],
["QLearning_L2F1_softmax-chosenQ-1"],
["QLearning_L2F1_softmax-sumQ-1"],
["ForagingCompareThreshold-reward"],
["ForagingCompareThreshold-value-1"],
["QLearning_L2F1_softmax-RPE"],
["ForagingCompareThreshold-RPE"],
]

# 3) ensure results folder
results_folder = '/root/capsule/scratch/correlation_results/'
os.makedirs(results_folder, exist_ok=True)

# 4) iterate sessions
for sess in spike_sorted_sessions:
    try:
        print(f"\n=== Processing session {sess} ===")

        # a) behavior summary
        generate_behavior_summary_combined(
            session_names=[sess],
            save_result=True,
            save_folder=results_folder,
            save_name=f"behavior_summary-{sess}.csv"
        )

        # b) firing rates (note the new call here)
        get_the_mean_firing_rate_combined(
            session_names=[sess],
            save_result=True,
            z_score = False,
            save_folder=results_folder,
            save_name=f"firing_rates-{sess}.csv"
        )
        df_combined_firing_rates    = smart_read_csv(os.path.join(results_folder, f"firing_rates-{sess}.csv"))
        df_combined_behavior_summary = smart_read_csv(os.path.join(results_folder, f"behavior_summary-{sess}.csv"))
        # c) correlations
        mv_df = correlate_firing_latent_multiple_variable(
            df_combined_firing_rates,
            df_combined_behavior_summary,
            variables=variables,
            correlation_model=[ "ARDL_model",'simple_LR'],
            save_result=True,
            save_name=f"correlations_multi-{sess}"
        )

    except Exception as e:
        print(f"!! Error in session {sess}: {e}")
        continue

# %%
from ephys_behavior import correlation_results_summary_combined

# 1) Let the function discover every correlations CSV automatically
summary = correlation_results_summary_combined(
    save_result=True,                       # write to disk
    save_name='sig_dir_all_sessions'    # custom file name
)

# %%
from general_utils import load_temporary_data

# path that you passed as   save_folder / (save_name + ".csv")
zarr_path = "/root/capsule/results/sig_dir_all_sessions.zarr"
ds = load_temporary_data(zarr_path)



print("Rows:", len(ds))
display(ds.head())             # in a notebook

# %%
import importlib
import ephys_behavior_visualization
importlib.reload(ephys_behavior_visualization)

# %%
from ephys_behavior_visualization import plot_angle_fraction_polar

# simple_LR
# Q-learning model Reward and SumQ
time_window='0.3_2_-1_0'
#time_window='0.3_2'
#time_window='-1_0'
include='all'
fig, ax, tbl = plot_angle_fraction_polar(
    ds=ds,
    filter_region='MD',
    time_window=time_window,
    col_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-coef",
    col_y="simple_LR-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-coef",
    col_pval_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-pval",
    col_pval_y="simple_LR-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-pval",
    include=include,
    angle_bin_deg=15,
    normalize='selected',
    start_angle_deg=0,
    show_reference_diagonals=True
)

fig, ax, tbl = plot_angle_fraction_polar(
    ds=ds,
    filter_region='',
    time_window=time_window,
    col_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-coef",
    col_y="simple_LR-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-coef",
    col_pval_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-pval",
    col_pval_y="simple_LR-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-pval",
    include=include,
    angle_bin_deg=15,
    normalize='selected',
    start_angle_deg=0,
    show_reference_diagonals=True
)



# Q-learning model Reward and ChosenQ

fig, ax, tbl = plot_angle_fraction_polar(
    ds=ds,
    filter_region='MD',
    time_window=time_window,
    col_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-coef",
    col_y="simple_LR-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-coef",
    col_pval_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-pval",
    col_pval_y="simple_LR-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-pval",
    include=include,
    angle_bin_deg=15,
    normalize='selected',
    start_angle_deg=0,
    show_reference_diagonals=True
)


fig, ax, tbl = plot_angle_fraction_polar(
    ds=ds,
    filter_region='',
    time_window=time_window,
    col_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-coef",
    col_y="simple_LR-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-coef",
    col_pval_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-pval",
    col_pval_y="simple_LR-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-pval",
    include=include,
    angle_bin_deg=15,
    normalize='selected',
    start_angle_deg=0,
    show_reference_diagonals=True
)


# threshold model
# 1) Plot for MD only


fig, ax, tbl = plot_angle_fraction_polar(
    ds=ds,
    filter_region='MD',
    time_window=time_window,
    col_x="simple_LR-ForagingCompareThreshold-reward-g2-s0-d0-coef",
    col_y="simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-coef",
    col_pval_x="simple_LR-ForagingCompareThreshold-reward-g2-s0-d0-pval",
    col_pval_y="simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-pval",
    include=include,
    angle_bin_deg=15,
    normalize='selected',
    start_angle_deg=0,
    show_reference_diagonals=True
)

# 
fig, ax, tbl = plot_angle_fraction_polar(
    ds=ds,
    filter_region='',
    time_window=time_window,
    col_x="simple_LR-ForagingCompareThreshold-reward-g2-s0-d0-coef",
    col_y="simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-coef",
    col_pval_x="simple_LR-ForagingCompareThreshold-reward-g2-s0-d0-pval",
    col_pval_y="simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-pval",
    include=include,
    angle_bin_deg=15,
    normalize='selected',
    start_angle_deg=0,
    show_reference_diagonals=True
)

# %%
from ephys_behavior_visualization import plot_angle_fraction_polar

# ARDL_model
# Q-learning model Reward and SumQ
time_window='0.3_2_-1_0'
#time_window='0.3_2'
#time_window='-1_0'
include='any'
fig, ax, tbl = plot_angle_fraction_polar(
    ds=ds,
    filter_region='MD',
    time_window=time_window,
    col_x="ARDL_model-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-coef",
    col_y="ARDL_model-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-coef",
    col_pval_x="ARDL_model-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-pval",
    col_pval_y="ARDL_model-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-pval",
    include=include,
    angle_bin_deg=15,
    normalize='selected',
    start_angle_deg=0,
    show_reference_diagonals=True
)

fig, ax, tbl = plot_angle_fraction_polar(
    ds=ds,
    filter_region='',
    time_window=time_window,
    col_x="ARDL_model-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-coef",
    col_y="ARDL_model-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-coef",
    col_pval_x="ARDL_model-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-pval",
    col_pval_y="ARDL_model-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-pval",
    include=include,
    angle_bin_deg=15,
    normalize='selected',
    start_angle_deg=0,
    show_reference_diagonals=True
)



# Q-learning model Reward and ChosenQ

fig, ax, tbl = plot_angle_fraction_polar(
    ds=ds,
    filter_region='MD',
    time_window=time_window,
    col_x="ARDL_model-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-coef",
    col_y="ARDL_model-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-coef",
    col_pval_x="ARDL_model-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-pval",
    col_pval_y="ARDL_model-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-pval",
    include=include,
    angle_bin_deg=15,
    normalize='selected',
    start_angle_deg=0,
    show_reference_diagonals=True
)


fig, ax, tbl = plot_angle_fraction_polar(
    ds=ds,
    filter_region='',
    time_window=time_window,
    col_x="ARDL_model-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-coef",
    col_y="ARDL_model-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-coef",
    col_pval_x="ARDL_model-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-pval",
    col_pval_y="ARDL_model-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-pval",
    include=include,
    angle_bin_deg=15,
    normalize='selected',
    start_angle_deg=0,
    show_reference_diagonals=True
)


# threshold model
# 1) Plot for MD only


fig, ax, tbl = plot_angle_fraction_polar(
    ds=ds,
    filter_region='MD',
    time_window=time_window,
    col_x="ARDL_model-ForagingCompareThreshold-reward-g2-s0-d0-coef",
    col_y="ARDL_model-ForagingCompareThreshold-value-1-g2-s0-d0-coef",
    col_pval_x="ARDL_model-ForagingCompareThreshold-reward-g2-s0-d0-pval",
    col_pval_y="ARDL_model-ForagingCompareThreshold-value-1-g2-s0-d0-pval",
    include=include,
    angle_bin_deg=15,
    normalize='selected',
    start_angle_deg=0,
    show_reference_diagonals=True
)

# 
fig, ax, tbl = plot_angle_fraction_polar(
    ds=ds,
    filter_region='',
    time_window=time_window,
    col_x="ARDL_model-ForagingCompareThreshold-reward-g2-s0-d0-coef",
    col_y="ARDL_model-ForagingCompareThreshold-value-1-g2-s0-d0-coef",
    col_pval_x="ARDL_model-ForagingCompareThreshold-reward-g2-s0-d0-pval",
    col_pval_y="ARDL_model-ForagingCompareThreshold-value-1-g2-s0-d0-pval",
    include=include,
    angle_bin_deg=15,
    normalize='selected',
    start_angle_deg=0,
    show_reference_diagonals=True
)

# %%
from ephys_behavior_visualization import plot_diagonal_significance
# simple_LR
# Q-learning model Reward and SumQ
time_window='0.3_2_-1_0'
#time_window='-1_0'
#time_window='0.3_2'
plot_diagonal_significance(
    ds=ds,
    filter_region='MD',
    time_window=time_window,
    col_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-coef",
    col_y="simple_LR-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-coef",
    col_pval_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-pval",
    col_pval_y="simple_LR-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-pval",
    point_size=1,
    fit_oval=False
)

plot_diagonal_significance(
    ds=ds,
    filter_region='',
    time_window=time_window,
    col_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-coef",
    col_y="simple_LR-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-coef",
    col_pval_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-pval",
    col_pval_y="simple_LR-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-pval",
    point_size=1,
    fit_oval=False
)



# Q-learning model Reward and ChosenQ
plot_diagonal_significance(
    ds=ds,
    filter_region='MD',
    time_window=time_window,
    col_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-coef",
    col_y="simple_LR-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-coef",
    col_pval_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-pval",
    col_pval_y="simple_LR-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-pval",
    point_size=1,
    fit_oval=False
)

plot_diagonal_significance(
    ds=ds,
    filter_region='',
    time_window=time_window,
    col_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-coef",
    col_y="simple_LR-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-coef",
    col_pval_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-pval",
    col_pval_y="simple_LR-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-pval",
    point_size=1,
    fit_oval=False
)


# threshold model
# 1) Plot for MD only
plot_diagonal_significance(
    ds=ds,
    filter_region='MD',
    time_window=time_window,
    col_x="simple_LR-ForagingCompareThreshold-reward-g2-s0-d0-coef",
    col_y="simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-coef",
    col_pval_x="simple_LR-ForagingCompareThreshold-reward-g2-s0-d0-pval",
    col_pval_y="simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-pval",
    point_size=1,
    fit_oval=False
)

# 
plot_diagonal_significance(
    ds=ds,
    filter_region='',
    time_window=time_window,
    col_x="simple_LR-ForagingCompareThreshold-reward-g2-s0-d0-coef",
    col_y="simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-coef",
    col_pval_x="simple_LR-ForagingCompareThreshold-reward-g2-s0-d0-pval",
    col_pval_y="simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-pval",
    point_size=1,
    fit_oval=False
)

# %%
from ephys_behavior_visualization import plot_diagonal_significance
# simple_LR
# Q-learning model Reward and SumQ
time_window='0.3_2'
plot_diagonal_significance(
    ds=ds,
    filter_region='MD',
    time_window=time_window,
    col_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-coef",
    col_y="simple_LR-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-coef",
    col_pval_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-pval",
    col_pval_y="simple_LR-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-pval",
    point_size=1,
    fit_oval=False
)

plot_diagonal_significance(
    ds=ds,
    filter_region='',
    time_window=time_window,
    col_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-coef",
    col_y="simple_LR-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-coef",
    col_pval_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-pval",
    col_pval_y="simple_LR-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-pval",
    point_size=1,
    fit_oval=False
)



# Q-learning model Reward and ChosenQ
plot_diagonal_significance(
    ds=ds,
    filter_region='MD',
    time_window=time_window,
    col_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-coef",
    col_y="simple_LR-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-coef",
    col_pval_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-pval",
    col_pval_y="simple_LR-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-pval",
    point_size=1,
    fit_oval=False
)

plot_diagonal_significance(
    ds=ds,
    filter_region='',
    time_window=time_window,
    col_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-coef",
    col_y="simple_LR-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-coef",
    col_pval_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-pval",
    col_pval_y="simple_LR-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-pval",
    point_size=1,
    fit_oval=False
)


# threshold model
# 1) Plot for MD only
plot_diagonal_significance(
    ds=ds,
    filter_region='MD',
    time_window=time_window,
    col_x="simple_LR-ForagingCompareThreshold-reward-g2-s0-d0-coef",
    col_y="simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-coef",
    col_pval_x="simple_LR-ForagingCompareThreshold-reward-g2-s0-d0-pval",
    col_pval_y="simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-pval",
    point_size=1,
    fit_oval=False
)

# 
plot_diagonal_significance(
    ds=ds,
    filter_region='',
    time_window=time_window,
    col_x="simple_LR-ForagingCompareThreshold-reward-g2-s0-d0-coef",
    col_y="simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-coef",
    col_pval_x="simple_LR-ForagingCompareThreshold-reward-g2-s0-d0-pval",
    col_pval_y="simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-pval",
    point_size=1,
    fit_oval=False
)

# %%
from ephys_behavior_visualization import plot_diagonal_significance
# simple_LR
# Q-learning model Reward and SumQ
time_window='0.3_2_-1_0'
plot_diagonal_significance(
    ds=ds,
    filter_region='MD',
    time_window=time_window,
    col_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-tval",
    col_y="simple_LR-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-tval",
    col_pval_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-pval",
    col_pval_y="simple_LR-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-pval",
    point_size=1,
    fit_oval=True
)

plot_diagonal_significance(
    ds=ds,
    filter_region='',
    time_window=time_window,
    col_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-tval",
    col_y="simple_LR-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-tval",
    col_pval_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-pval",
    col_pval_y="simple_LR-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-pval",
    point_size=1
)



# Q-learning model Reward and ChosenQ
plot_diagonal_significance(
    ds=ds,
    filter_region='MD',
    time_window=time_window,
    col_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-tval",
    col_y="simple_LR-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-tval",
    col_pval_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-pval",
    col_pval_y="simple_LR-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-pval",
    point_size=1
)

plot_diagonal_significance(
    ds=ds,
    filter_region='',
    time_window=time_window,
    col_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-tval",
    col_y="simple_LR-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-tval",
    col_pval_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-pval",
    col_pval_y="simple_LR-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-pval",
    point_size=1
)


# threshold model
# 1) Plot for MD only
plot_diagonal_significance(
    ds=ds,
    filter_region='MD',
    time_window=time_window,
    col_x="simple_LR-ForagingCompareThreshold-reward-g2-s0-d0-tval",
    col_y="simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-tval",
    col_pval_x="simple_LR-ForagingCompareThreshold-reward-g2-s0-d0-pval",
    col_pval_y="simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-pval",
    point_size=1
)

# 
plot_diagonal_significance(
    ds=ds,
    filter_region='',
    time_window=time_window,
    col_x="simple_LR-ForagingCompareThreshold-reward-g2-s0-d0-tval",
    col_y="simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-tval",
    col_pval_x="simple_LR-ForagingCompareThreshold-reward-g2-s0-d0-pval",
    col_pval_y="simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-pval",
    point_size=1
)

# %%
from ephys_behavior_visualization import plot_diagonal_significance
# simple_LR
# Q-learning model Reward and SumQ
time_window='-1_0'
plot_diagonal_significance(
    ds=ds,
    filter_region='MD',
    time_window=time_window,
    col_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-tval",
    col_y="simple_LR-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-tval",
    col_pval_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-pval",
    col_pval_y="simple_LR-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-pval",
    point_size=1
)

plot_diagonal_significance(
    ds=ds,
    filter_region='',
    time_window=time_window,
    col_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-tval",
    col_y="simple_LR-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-tval",
    col_pval_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-pval",
    col_pval_y="simple_LR-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-pval",
    point_size=1
)



# Q-learning model Reward and ChosenQ
plot_diagonal_significance(
    ds=ds,
    filter_region='MD',
    time_window=time_window,
    col_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-tval",
    col_y="simple_LR-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-tval",
    col_pval_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-pval",
    col_pval_y="simple_LR-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-pval",
    point_size=1
)

plot_diagonal_significance(
    ds=ds,
    filter_region='',
    time_window=time_window,
    col_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-tval",
    col_y="simple_LR-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-tval",
    col_pval_x="simple_LR-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-pval",
    col_pval_y="simple_LR-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-pval",
    point_size=1
)


# threshold model
# 1) Plot for MD only
plot_diagonal_significance(
    ds=ds,
    filter_region='MD',
    time_window=time_window,
    col_x="simple_LR-ForagingCompareThreshold-reward-g2-s0-d0-tval",
    col_y="simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-tval",
    col_pval_x="simple_LR-ForagingCompareThreshold-reward-g2-s0-d0-pval",
    col_pval_y="simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-pval",
    point_size=1
)

# 
plot_diagonal_significance(
    ds=ds,
    filter_region='',
    time_window=time_window,
    col_x="simple_LR-ForagingCompareThreshold-reward-g2-s0-d0-tval",
    col_y="simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-tval",
    col_pval_x="simple_LR-ForagingCompareThreshold-reward-g2-s0-d0-pval",
    col_pval_y="simple_LR-ForagingCompareThreshold-value-1-g2-s0-d0-pval",
    point_size=1
)

# %%
# Q-learning model Reward and SumQ
time_window='-1_0'
time_window='0.3_2'
plot_diagonal_significance(
    ds=ds,
    filter_region='MD',
    time_window=time_window,
    col_x="ARDL_model-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-tval",
    col_y="ARDL_model-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-tval",
    col_pval_x="ARDL_model-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-pval",
    col_pval_y="ARDL_model-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-pval",
    point_size=1
)

plot_diagonal_significance(
    ds=ds,
    filter_region='',
    time_window=time_window,
    col_x="ARDL_model-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-tval",
    col_y="ARDL_model-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-tval",
    col_pval_x="ARDL_model-QLearning_L2F1_CK1_softmax-reward-g1-s0-d0-pval",
    col_pval_y="ARDL_model-QLearning_L2F1_CK1_softmax-sumQ-1-g1-s0-d0-pval",
    point_size=1
)



# Q-learning model Reward and ChosenQ
plot_diagonal_significance(
    ds=ds,
    filter_region='MD',
    time_window=time_window,
    col_x="ARDL_model-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-tval",
    col_y="ARDL_model-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-tval",
    col_pval_x="ARDL_model-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-pval",
    col_pval_y="ARDL_model-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-pval",
    point_size=1
)

plot_diagonal_significance(
    ds=ds,
    filter_region='',
    time_window=time_window,
    col_x="ARDL_model-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-tval",
    col_y="ARDL_model-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-tval",
    col_pval_x="ARDL_model-QLearning_L2F1_CK1_softmax-reward-g0-s0-d0-pval",
    col_pval_y="ARDL_model-QLearning_L2F1_CK1_softmax-chosenQ-1-g0-s0-d0-pval",
    point_size=1
)


# threshold model
# 1) Plot for MD only
plot_diagonal_significance(
    ds=ds,
    filter_region='MD',
    time_window=time_window,
    col_x="ARDL_model-ForagingCompareThreshold-reward-g2-s0-d0-tval",
    col_y="ARDL_model-ForagingCompareThreshold-value-1-g2-s0-d0-tval",
    col_pval_x="ARDL_model-ForagingCompareThreshold-reward-g2-s0-d0-pval",
    col_pval_y="ARDL_model-ForagingCompareThreshold-value-1-g2-s0-d0-pval",
    point_size=1
)

# 
plot_diagonal_significance(
    ds=ds,
    filter_region='',
    time_window=time_window,
    col_x="ARDL_model-ForagingCompareThreshold-reward-g2-s0-d0-tval",
    col_y="ARDL_model-ForagingCompareThreshold-value-1-g2-s0-d0-tval",
    col_pval_x="ARDL_model-ForagingCompareThreshold-reward-g2-s0-d0-pval",
    col_pval_y="ARDL_model-ForagingCompareThreshold-value-1-g2-s0-d0-pval",
    point_size=1
)

# %%
# all neurons
fraction=[42.4,42.8,42.6,15.8,24.1,35.6]
label=['QLearning_reward','QLearning_reward','CTT_reward','QLearning_chosenQ','QLearning_sumQ','CTT_value']

# MD neurons
fraction=[48.6,49.0,49.2,25.4,31.3,44.7]
label=['QLearning_reward','QLearning_reward','CTT_reward','QLearning_chosenQ','QLearning_sumQ','CTT_value']

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fractions for each correlation pair
reward_fractions = [48.6,49.0,49.2]
other_fractions = [25.4,31.3,44.7]

# Labels and corresponding models for each comparison
other_labels = ['ChosenQ', 'SumQ', 'Value']
models = ['QLearning', 'QLearning', 'CTT']
labels_with_model = [f'{lbl}\n({model})' for lbl, model in zip(other_labels, models)]

# Set up the x-axis positions and bar width
x = np.arange(len(other_labels))
width = 0.35

fig, ax = plt.subplots()
# Plot reward fractions
ax.bar(x - width/2, reward_fractions, width, label='Reward')
# Plot other variable fractions
ax.bar(x + width/2, other_fractions, width, label='Other Variable')

# Add labels and title
ax.set_xticks(x)
ax.set_xticklabels(labels_with_model)
ax.set_ylabel('Significance Fraction (%)')
ax.set_title('Fraction of Significant Correlations by Model')
ax.legend()

plt.show()

# %%
summary_path = "/root/capsule/results/sig_dir_all_sessions.zarr"
from ephys_behavior_visualization import scatter_summary_multi
from general_utils import load_temporary_data

# path that you passed as   save_folder / (save_name + ".csv")
csv_path = "/root/capsule/results/sig_dir_all_sessions.zarr"
ds = load_temporary_data(csv_path)


#ds = ds[ds['brain_region'] == 'MD']

# 2) two prefixes in one group  → scatter plot appears




scatter_summary_multi(
    ds,
    compare_variables=[["ARDL_model-q_learning_Y1-reward-g2-s0-tval", "ARDL_model-q_learning_Y1-chosenQ-1-g-s0-tval"]],
    x_label='Reward t-statistic',
    y_label='ChosenQ t-statistic'
)


scatter_summary_multi(
    ds,
    compare_variables=[["ARDL_model-q_learning_Y1-reward-g1-s0-coef", "ARDL_model-q_learning_Y1-chosenQ-1-g1-s0-coef"]],
    x_label='Reward coefficient',
    y_label='ChosenQ coefficient',
    x_limit=(-10,10),
    y_limit=(-10,10)
)


scatter_summary_multi(
    ds,
    compare_variables=[["ARDL_model-q_learning_Y1-reward-g1-s0-pval", "ARDL_model-q_learning_Y1-chosenQ-1-g1-s0-pval"]],
    x_label='Reward p-value',
    y_label='ChosenQ p-value',
    x_limit=(0,1),
    y_limit=(0,1)
)

# %%
summary_path = "/root/capsule/results/sig_dir_all_sessions.zarr"
from ephys_behavior_visualization import fraction_significant_multi
from general_utils import load_temporary_data

# path that you passed as   save_folder / (save_name + ".csv")
csv_path = "/root/capsule/results/sig_dir_all_sessions.zarr"
ds = load_temporary_data(csv_path)


fraction_significant_multi(
    ds,
    compare_variables=["ARDL_model-q_learning_Y1-deltaQ-g0-s0-pval", "simple_LR-q_learning_Y1-deltaQ-g0-s0-pval"],
    variable_labels=['DeltaQ(ARDL_model)','DeltaQ(simple_LR)']
)


fraction_significant_multi(
    ds,
    compare_variables=["ARDL_model-q_learning_Y1-sumQ-g0-s0-pval", "simple_LR-q_learning_Y1-sumQ-g0-s0-pval"],
    variable_labels=['SumQ(ARDL_model)','SumQ(simple_LR)']
)

fraction_significant_multi(
    ds,
    compare_variables=["ARDL_model-q_learning_Y1-sumQ-g0-s-1-pval", "simple_LR-q_learning_Y1-sumQ-g0-s-1-pval"],
    variable_labels=['SumQ(ARDL_model)','SumQ(simple_LR)']
)

# %%
fraction_significant_multi(
    ds,
    compare_variables=["ARDL_model-q_learning_Y1-RPE-g0-s-1-pval", "simple_LR-q_learning_Y1-RPE-g0-s-1-pval"],
    variable_labels=['sumQ(ARDL_model)','sumQ(simple_LR)']
)

# %%
from behavior_utils import load_and_combine_csvs

combined_df = load_and_combine_csvs("/root/capsule/results", "behavior_summary-*.csv")
print(combined_df.shape)

# %%
from ephys_behavior_visualization import fit_and_plot_by_session
from behavior_utils import load_and_combine_csvs

combined_df = load_and_combine_csvs("/root/capsule/results", "behavior_summary-*.csv")


fit_results = fit_and_plot_by_session(
    combined_df,
     "q_learning_Y1-deltaQ",
     "q_learning_Y1-sumQ",
     x_label='deltaQ',
     y_label='SumQ'
 )

# %%
from general_visualization import plot_behavior_session
from nwb_utils import NWBUtils
from model_fitting import fit_q_learning_model

nwb_data = NWBUtils.read_ophys_or_behavior_nwb(
    session_name="776293_2025-02-14_15-19-17"
)
fitted_latent=fit_q_learning_model(nwb_data)

plot_behavior_session(nwb_data=nwb_data,
                    latent_name="right_choice_probability",
                fitted_latent = fitted_latent
    
    )

# %%
from behavior_utils import get_fitted_model_names, get_fitted_latent, extract_fitted_data
from nwb_utils import NWBUtils
from general_visualization import plot_behavior_session
from nwb_utils import NWBUtils
from model_fitting import fit_q_learning_model

nwb_data = NWBUtils.read_ophys_or_behavior_nwb(
    session_name="753124_2024-12-10_17-24-56"
)

# get fitted model names
get_fitted_model_names(session_name="753124_2024-12-10_17-24-56")
# get_fitted_latent
get_fitted_latent(session_name="753124_2024-12-10",model_alias='ForagingCompareThreshold')
# extract fitted data
a=extract_fitted_data(nwb_behavior_data=nwb_data,
                    session_name="753124_2024-12-10_17-24-56",
                    model_alias='QLearning_L2F1_CK1_softmax',
                    latent_name='RPE')

# %%
from ephys_behavior import project_psth_per_trial
from general_utils import find_ephys_sessions
from nwb_utils import NWBUtils
from general_utils import load_temporary_data
import pandas as pd

# 1) Find all spike‐sorted sessions
_, _, spike_sorted_sessions = find_ephys_sessions()
print("Sessions to process:", spike_sorted_sessions)

# 2) Load your correlation table once
zarr_path = "/root/capsule/results/sig_dir_all_sessions.zarr"
corr_df = load_temporary_data(zarr_path)

# 3) Define all the switch‐based trial types you care about
switch_types = [
    'switch_trial',
    'switch_trial_reward',
    'switch_trial_noreward',
    'switch_LR',
    'switch_LR_reward',
    'switch_LR_noreward',
    'switch_RL',
    'switch_RL_reward',
    'switch_RL_noreward',
]

# 4) Loop over sessions and switch types, collect results
all_proj = []
for session_name in spike_sorted_sessions:
    print(f"Processing session {session_name}…")
    nwb_data, tag = NWBUtils.combine_nwb(session_name=session_name)
    
    for st in switch_types:
        df = project_psth_per_trial(
            nwb_data   = nwb_data,
            corr_df    = corr_df,
            trial_type = st,
            coef_direction = 'positive'
        )
        # annotate which session and switch type
        if df is None:
             continue
        df["session_name"] = session_name
        df["switch_type"]  = st
        all_proj.append(df)

# 5) Concatenate into one big DataFrame
proj_df_all = pd.concat(all_proj, ignore_index=True)

# 6) Quick sanity‐checks
print("Trials per session:")
print(proj_df_all.session_name.value_counts(), "\n")

print("Trials per switch type:")
print(proj_df_all.switch_type.value_counts(), "\n")

print("Preview:")
print(proj_df_all.head())

# %%
import numpy as np

1./np.array([1,2,2])

# %%
# 5) Concatenate into one big DataFrame
proj_df_all = pd.concat(all_proj, ignore_index=True)

# 6) Quick sanity‐checks
print("Trials per session:")
print(proj_df_all.session_name.value_counts(), "\n")

print("Trials per switch type:")
print(proj_df_all.switch_type.value_counts(), "\n")

print("Preview:")
print(proj_df_all.head())

# %%
from ephys_behavior_visualization import plot_projection

# proj_df_all is your concatenated DataFrame from before

sessions = proj_df_all['session_name'].unique()

for session in sessions:
    df_sess = proj_df_all[proj_df_all['session_name'] == session]
    # assume every row in df_sess has the same n_units
    for st in ['switch_trial']:
        df_st = df_sess[df_sess['switch_type'] == st]
        if df_st.empty:
            continue

        # extract number of units from the proj_df
        n_units = int(df_st['n_units'].iloc[0])
        print(f"\n--- Session: {session} | Switch type: {st} | Units: {n_units} ---")

        # 1) raw trials
        plot_projection(
            df_st,
            title=f"{session} – {st}",
            unit_number=n_units
        )

        # 2) mean ±1 SD
        plot_projection(
            df_st,
            average=True,
            title=f"{session} – {st} (mean±SD)",
            unit_number=n_units
        )

        # 3) baseline & quantiles
        plot_projection(
            df_st,
            baseline_window=(-1.0, 0.0),
            n_quantiles=4,
            title=f"{session} – {st} (baseline & quantiles)",
            unit_number=n_units
        )

# %%
plot_projection(
    df_st,
    baseline_window=(-1.0, 0),
    n_quantiles=4,
    title=f"{session} – {st} (baseline & quantiles)"
)

# %%
# create and save PSTH
from nwb_utils import NWBUtils
from behavior_utils import extract_fitted_data, find_trials,get_fitted_model_names,generate_behavior_summary
from create_psth import extract_neuron_psth_to_zarr

session_name='764790_2024-12-19_16-11-34_sorted_2025-02-21_14-46-33'
#session_name='764790_2024-12-19_16-11-34'
print(get_fitted_model_names(session_name=session_name))

nwb_data,tag=NWBUtils.combine_nwb(session_name=session_name)

# %%
from ephys_behavior_visualization import plot_raster_graph
plot_raster_graph(nwb_data=nwb_data,unit_indices=[10],trial_types=['rewarded'])

# %%
# create and save PSTH
from nwb_utils import NWBUtils
from behavior_utils import extract_fitted_data, find_trials,get_fitted_model_names,generate_behavior_summary
from create_psth import extract_neuron_psth_to_zarr

session_name='764787_2024-12-11_15-01-15_sorted_2025-02-21_17-11-57'
#session_name='764790_2024-12-19_16-11-34'
print(get_fitted_model_names(session_name=session_name))

nwb_data,tag=NWBUtils.combine_nwb(session_name=session_name)

psth_da = extract_neuron_psth_to_zarr(
    nwb_data       = nwb_data,
    align_to_event = ["go_cue","reward_go_cue_start"],
    time_window    = (-6, 6),
    bin_size       = 0.02,
    save_folder    = "/root/capsule/results",
    save_name      = "psth_mouse123",
)

# %%
from create_psth import  load_psth_raster_from_zarr, mean_firing_rate_matrix,load_zarr
from behavior_utils import find_trials

# 0.  Load the pre‑computed PSTH cube
#psth_da = load_psth_raster_from_zarr("/root/capsule/results/psth_mouse123.zarr",align_to_event='go_cue',load_type='both')
psth_full = load_zarr("/root/capsule/results/psth_mouse123.zarr")

# %%
psth_full

# %%
from create_psth import load_psth_raster_subset
psth,raster=load_psth_raster_subset(psth_full,align_to_event='go_cue')

# %%
# create and save PSTH
from nwb_utils import NWBUtils
from behavior_utils import extract_fitted_data, find_trials,get_fitted_model_names,generate_behavior_summary
from ephys_behavior import extract_columns_by_filters
from create_psth import extract_neuron_psth_to_zarr
from general_utils import load_temporary_data
import numpy as np
from pathlib import Path
session_name='764787_2024-12-11_15-01-15_sorted_2025-02-21_17-11-57'

#session_name='764790_2024-12-19_16-11-34'
print(get_fitted_model_names(session_name=session_name))

nwb_data,tag=NWBUtils.combine_nwb(session_name=session_name)


# 2) Load your correlation table once
zarr_path = "/root/capsule/results/sig_dir_all_sessions.zarr"
corr_df = load_temporary_data(zarr_path)


# Validate coef_col and derive pval column
coef_col = "simple_LR-ForagingCompareThreshold-value-1-g7-s0-d0-coef"
pval_col = coef_col.replace("-coef", "-pval")

# 1) extract unit → coef & p-val mapping
col_names = ["unit_index", coef_col, pval_col, "source_file"]
filters = {"time_window": "-1_0", "z_score": False}
coef_tbl = extract_columns_by_filters(
    corr_df=corr_df,
    col_names=col_names,
    filters=filters
)

session_base = Path(nwb_data.session_id).stem
session_base=session_base.replace('behavior_','')
coef_tbl = coef_tbl[coef_tbl["source_file"].str.contains(session_base)]

coef_direction="positive"
p_value=0.05
if coef_direction == "positive":
    coef_tbl = coef_tbl[coef_tbl[coef_col] > 0]
elif coef_direction == "negative":
    coef_tbl = coef_tbl[coef_tbl[coef_col] < 0]

coef_tbl = coef_tbl[coef_tbl[pval_col] < p_value]


unit_idx_list = list(dict.fromkeys(coef_tbl["unit_index"].to_list()))

# ---------------------------------------------------------------------
# EXAMPLE ── integrate with your existing code
# ---------------------------------------------------------------------
from create_psth import load_psth_raster_from_zarr, load_psth_raster_from_zarr, mean_firing_rate_matrix, plot_psth_raster_for_units,load_zarr
from behavior_utils import find_trials

# 0.  Load the pre‑computed PSTH cube
psth_da = load_zarr("/root/capsule/results/psth_mouse123.zarr")

# 1.  Pick trials of interest
# 2) convert → numpy array  (enables vectorised −1)
switch_trials=find_trials(nwb_data,'switch_trial')
switch_trials = np.asarray(switch_trials, dtype=int)

# 3) one trial earlier
previous_trial_ids = switch_trials

valid_prev_trial_ids  = previous_trial_ids[previous_trial_ids >= 0]  # safety

# 2.  Plot PSTH for three units over those trials
fig = plot_psth_raster_for_units(
    source=psth_da, 
    align_to_event='go_cue',
    unit_ids=unit_idx_list[110:112],           
    trial_ids=[[valid_prev_trial_ids],[valid_prev_trial_ids-1]],
    time_window=(-3, 6),
    save_path="/root/capsule/results/",
    plot_type='mean'
)

# %%
valid_prev_trial_ids

# %%
# create and save PSTH
from nwb_utils import NWBUtils
from behavior_utils import extract_fitted_data, find_trials,get_fitted_model_names,generate_behavior_summary
from create_psth import extract_neuron_psth_to_zarr

session_name='764790_2024-12-19_16-11-34_sorted_2025-02-21_14-46-33'
#session_name='764790_2024-12-19_16-11-34'
print(get_fitted_model_names(session_name=session_name))

nwb_data,tag=NWBUtils.combine_nwb(session_name=session_name)

# %%
from create_psth import plot_psth_raster_for_units
fig = plot_psth_raster_for_units(
    source=psth_da, 
    align_to_event='go_cue',
    unit_ids=unit_idx_list,           
    trial_types=['rewarded','unrewarded'],
    time_window=(-3, 6),
    save_path="psth_three_units.png",
    plot_type='mean',
    nwb_data=nwb_data,
    y_mode="auto_per_unit", 
    sharey=False
)

# %%
# create and save PSTH
from nwb_utils import NWBUtils
from behavior_utils import extract_fitted_data, find_trials,get_fitted_model_names,generate_behavior_summary
from ephys_behavior import extract_columns_by_filters
from create_psth import extract_neuron_psth_to_zarr
from general_utils import load_temporary_data,smart_read_csv
import numpy as np
from pathlib import Path
import os
session_name='ecephys_764787_2024-12-11_15-01-15_sorted_2025-02-21_17-11-57'

#session_name='764790_2024-12-19_16-11-34'
print(get_fitted_model_names(session_name=session_name))

nwb_data,tag=NWBUtils.combine_nwb(session_name=session_name)


# 2) Load your correlation table once
zarr_path = "/root/capsule/results/sig_dir_all_sessions.zarr"
corr_df = load_temporary_data(zarr_path)


# Validate coef_col and derive pval column
coef_col = "simple_LR-ForagingCompareThreshold-value-1-g7-s0-d0-coef"
pval_col = coef_col.replace("-coef", "-pval")

# 1) extract unit → coef & p-val mapping
col_names = ["unit_index", coef_col, pval_col, "source_file"]
filters = {"time_window": "-1_0", "z_score": False}
coef_tbl = extract_columns_by_filters(
    corr_df=corr_df,
    col_names=col_names,
    filters=filters
)

session_base = Path(nwb_data.session_id).stem
session_base=session_base.replace('behavior_','')
coef_tbl = coef_tbl[coef_tbl["source_file"].str.contains(session_base)]

coef_direction="positive"
p_value=0.01
if coef_direction == "positive":
    coef_tbl = coef_tbl[coef_tbl[coef_col] > 0]
elif coef_direction == "negative":
    coef_tbl = coef_tbl[coef_tbl[coef_col] < 0]

coef_tbl = coef_tbl[coef_tbl[pval_col] < p_value]


unit_idx_list = list(dict.fromkeys(coef_tbl["unit_index"].to_list()))

# ---------------------------------------------------------------------
# EXAMPLE ── integrate with your existing code
# ---------------------------------------------------------------------
from create_psth import load_psth_subset, load_psth_from_zarr, mean_firing_rate_matrix, plot_psth_for_units
from behavior_utils import find_trials

psth_da = load_psth_from_zarr("/root/capsule/results/psth_mouse123.zarr")

mean_firing_rate=mean_firing_rate_matrix(
    source=psth_da,
    time_window=(-1,0),
)
switch_trials=find_trials(nwb_data,'switch_trial')
switch_trials = np.asarray(switch_trials, dtype=int)+1

no_response_trials=find_trials(nwb_data,'no_response')
no_response_trials = np.asarray(no_response_trials, dtype=int)

results_folder="/root/capsule/results/"
df_combined_behavior_summary = smart_read_csv(os.path.join(results_folder, f"behavior_summary-{session_name}.csv"))

latent_clean=df_combined_behavior_summary['ForagingCompareThreshold-value-1'][0]

# 1) How many trials you started with:
n_trials = mean_firing_rate.shape[-1]   # or len(latent)

# 2) Build the array of all original trial indices:
all_trials = np.arange(n_trials)

# 3) Drop the no-response trials to get your “clean” trial indices:
clean_trials = np.setdiff1d(all_trials, no_response_trials)

# 4) Now find which positions in clean_trials are your switch trials:
#    np.isin(clean_trials, switch_trials) is a boolean mask of length len(clean_trials)
#    np.where(…)[0] gives you the integer locations
switch_in_clean = np.where(np.isin(clean_trials, switch_trials))[0]

keep_mask = ~np.isin(mean_firing_rate.coords["trial_index"].values, no_response_trials)
mean_firing_rate_clean=mean_firing_rate.isel(trial=keep_mask)

latent_clean=np.array(latent_clean)

# %%
import matplotlib.pyplot as plt
for ui in unit_idx_list:
    # get firing‐rate vector
    pos = np.where(mean_firing_rate_clean.unit_index.values == ui)[0][0]
    fr_unit = mean_firing_rate_clean.isel(unit=pos).values

    fig, ax = plt.subplots(figsize=(6,4))
    # all trials in blue
    ax.scatter(
        latent_clean,fr_unit,
        alpha=0.6,
        color='C0',
        label='Other trials'
    )
    # switch trials in orange
    ax.scatter(
        latent_clean[switch_in_clean],fr_unit[switch_in_clean],
        color='C1',
        s=80,
        label='Switch trials'
    )

    ax.set_ylabel('Mean firing rate (Hz)')
    ax.set_xlabel('ForagingCompareThreshold-value-1')
    ax.set_title(f'Unit {ui}')
    ax.legend(loc='best')
    plt.tight_layout()
    plt.show()
    plt.close(fig)

# %%
# create and save PSTH
from nwb_utils import NWBUtils
from behavior_utils import extract_fitted_data, find_trials,get_fitted_model_names,generate_behavior_summary
from ephys_behavior import extract_columns_by_filters
from create_psth import extract_neuron_psth_to_zarr
from general_utils import load_temporary_data,smart_read_csv
import numpy as np
from pathlib import Path
import os
session_name='ecephys_764787_2024-12-11_15-01-15_sorted_2025-02-21_17-11-57'

#session_name='764790_2024-12-19_16-11-34'
print(get_fitted_model_names(session_name=session_name))

nwb_data,tag=NWBUtils.combine_nwb(session_name=session_name)


# 2) Load your correlation table once
zarr_path = "/root/capsule/results/sig_dir_all_sessions.zarr"
corr_df = load_temporary_data(zarr_path)


# Validate coef_col and derive pval column
coef_col = "simple_LR-ForagingCompareThreshold-value-1-g7-s0-d0-coef"
pval_col = coef_col.replace("-coef", "-pval")

# 1) extract unit → coef & p-val mapping
col_names = ["unit_index", coef_col, pval_col, "source_file"]
filters = {"time_window": "-1_0", "z_score": False}
coef_tbl = extract_columns_by_filters(
    corr_df=corr_df,
    col_names=col_names,
    filters=filters
)

session_base = Path(nwb_data.session_id).stem
coef_tbl = coef_tbl[coef_tbl["source_file"].str.contains(session_base)]

coef_direction="negative"
p_value=0.01
if coef_direction == "positive":
    coef_tbl = coef_tbl[coef_tbl[coef_col] > 0]
elif coef_direction == "negative":
    coef_tbl = coef_tbl[coef_tbl[coef_col] < 0]

coef_tbl = coef_tbl[coef_tbl[pval_col] < p_value]


unit_idx_list = list(dict.fromkeys(coef_tbl["unit_index"].to_list()))

# ---------------------------------------------------------------------
# EXAMPLE ── integrate with your existing code
# ---------------------------------------------------------------------
from create_psth import load_psth_subset, load_psth_from_zarr, mean_firing_rate_matrix, plot_psth_for_units
from behavior_utils import find_trials

psth_da = load_psth_from_zarr("/root/capsule/results/psth_mouse123.zarr")

mean_firing_rate=mean_firing_rate_matrix(
    source=psth_da,
    time_window=(-1,0),
)
switch_trials=find_trials(nwb_data,'switch_trial')
switch_trials = np.asarray(switch_trials, dtype=int)

no_response_trials=find_trials(nwb_data,'no_response')
no_response_trials = np.asarray(no_response_trials, dtype=int)

results_folder="/root/capsule/results/"
df_combined_behavior_summary = smart_read_csv(os.path.join(results_folder, f"behavior_summary-{session_name}.csv"))
df_combined_behavior_summary = smart_read_csv(os.path.join(results_folder, f"firing_rates-{session_name}.csv"))


latent_clean=df_combined_behavior_summary['ForagingCompareThreshold-value-1'][0]

# 1) How many trials you started with:
n_trials = mean_firing_rate.shape[-1]   # or len(latent)

# 2) Build the array of all original trial indices:
all_trials = np.arange(n_trials)

# 3) Drop the no-response trials to get your “clean” trial indices:
clean_trials = np.setdiff1d(all_trials, no_response_trials)

# 4) Now find which positions in clean_trials are your switch trials:
#    np.isin(clean_trials, switch_trials) is a boolean mask of length len(clean_trials)
#    np.where(…)[0] gives you the integer locations
switch_in_clean = np.where(np.isin(clean_trials, switch_trials))[0]

keep_mask = ~np.isin(mean_firing_rate.coords["trial_index"].values, no_response_trials)
mean_firing_rate_clean=mean_firing_rate.isel(trial=keep_mask)

latent_clean=np.array(latent_clean)
