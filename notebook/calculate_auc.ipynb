# %%
# calculate per-unit AUC for each session (all units)

import numpy as np
from pathlib import Path

from calculate_auc import per_unit_auc_from_psth
from create_psth import load_zarr
from general_utils import smart_read_csv, find_ephys_sessions

# ---------------------------------------------------------------------
# User parameters
# ---------------------------------------------------------------------
binsize = "0.2"
align = "go_cue"

# Time windows over which to average PSTH for per-unit AUC
time_windows = [[0.3, 2], [-1, 0]]

# Trial types used for defining class A and class B
trial_types = ["right_choice_trials", "left_choice_trials"]
trial_types = ["rewarded_trials", "unrewarded_trials"]

# AUC-related parameters
n_trials_per_class = 100   # None => use min(nA, nB); or set an int like 15
n_repeats = 100
min_trials_per_class = 8
random_state = 0

psth_root = Path("/root/capsule/scratch/psth_results")
behavior_root = Path("/root/capsule/scratch/behavior_summary")
auc_root = Path("/root/capsule/scratch/AUC_results")
auc_root.mkdir(parents=True, exist_ok=True)

# Metadata
metadata_path = Path("/root/capsule/scratch/qc_passed_units_metadata_all_sessions.csv")
metadata = smart_read_csv(metadata_path)

# ---------------------------------------------------------------------
# Helpers
# ---------------------------------------------------------------------
def _clean_ids(x):
    """
    Convert behavior_summary column (x) into an integer array of trial IDs.
    Assumes x[0] contains the list/array of trial IDs.
    """
    arr = np.asarray(x[0])
    if arr.dtype.kind in {"f"}:  # float -> may contain NaN
        arr = arr[~np.isnan(arr)]
    return arr.astype(int)


# ---------------------------------------------------------------------
# Main loop
# ---------------------------------------------------------------------
sessions = find_ephys_sessions()
failed_sessions_auc = []

print("Total sessions (index 2):", len(sessions[2]))

for session in sessions[2]:
    print("\n==============================")
    print(f"Session: {session}")
    print("==============================")

    try:
        # The metadata uses “sorted_session_name”
        sorted_session_name = session

        psth_path = psth_root / f"{session}_{binsize}s.zarr"
        behavior_path = behavior_root / f"behavior_summary-{session}.csv"

        psth_da = load_zarr(str(psth_path))
        df = smart_read_csv(str(behavior_path))

        # Pull trial-id arrays and clean up
        typeA_ids = _clean_ids(df[trial_types[0]])
        typeB_ids = _clean_ids(df[trial_types[1]])

        print(f"  {trial_types[0]}: {len(typeA_ids)} trials")
        print(f"  {trial_types[1]}: {len(typeB_ids)} trials")

        # -------------------------------------------------------------
        # Loop over time windows for AUC calculation (all units)
        # -------------------------------------------------------------
        for time_window in time_windows:
            tw0, tw1 = time_window

            save_path = (
                auc_root
                / f"AUC_{session}_{trial_types[0]}_{trial_types[1]}_TW_{tw0}_{tw1}.zarr"
            )

            try:
                res = per_unit_auc_from_psth(
                    psth_da=psth_da,
                    trial_ids_typeA=typeA_ids,
                    trial_ids_typeB=typeB_ids,
                    align=align,
                    time_window=tuple(time_window),
                    n_trials_per_class=n_trials_per_class,
                    n_repeats=n_repeats,
                    min_trials_per_class=min_trials_per_class,
                    random_state=random_state,
                    unit_ids=None,            # all units
                    metadata=metadata,        # >>> ADDED
                    sorted_session_name=sorted_session_name,   # >>> ADDED
                    metadata_unit_col="unit_index",            # >>> ADDED
                    save_path=str(save_path),
                    save_format="zarr",
                    overwrite=True,
                )

                if res.get("skipped", False):
                    print(
                        f"    Skip time window {time_window}: "
                        f"{res.get('reason', 'no reason provided')}"
                    )
                else:
                    print(
                        f"    ✔ Finished AUC time window {time_window}: "
                        f"{res.get('saved_to', str(save_path))}"
                    )

            except Exception as e:
                print(f"    ❌ Error in AUC time window {time_window}: {e}")
                failed_sessions_auc.append(
                    (session, f"time_window={time_window}", str(e))
                )

    except Exception as e:
        print(f"❌ ERROR loading session {session}: {e}")
        failed_sessions_auc.append((session, "load_failure", str(e)))


print("\n==============================")
print("All AUC calculations done (all units).")
print("==============================")
if failed_sessions_auc:
    print("Failed items:")
    for f in failed_sessions_auc:
        print(" -", f)
else:
    print("No errors")
# Out:
# Total sessions (index 2): 41
#
# ==============================
# Session: ecephys_753124_2024-12-10_17-24-56_sorted_2024-12-13_09-48-25
# ==============================
#   rewarded_trials: 142 trials
#   unrewarded_trials: 218 trials
#     ✔ Finished AUC time window [0.3, 2]: /root/capsule/scratch/AUC_results/AUC_ecephys_753124_2024-12-10_17-24-56_sorted_2024-12-13_09-48-25_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     ✔ Finished AUC time window [-1, 0]: /root/capsule/scratch/AUC_results/AUC_ecephys_753124_2024-12-10_17-24-56_sorted_2024-12-13_09-48-25_rewarded_trials_unrewarded_trials_TW_-1_0.zarr
#
# ==============================
# Session: ecephys_753125_2024-10-09_10-50-19_sorted_2024-11-09_20-03-58
# ==============================
#   rewarded_trials: 299 trials
#   unrewarded_trials: 256 trials
#     ✔ Finished AUC time window [0.3, 2]: /root/capsule/scratch/AUC_results/AUC_ecephys_753125_2024-10-09_10-50-19_sorted_2024-11-09_20-03-58_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     ✔ Finished AUC time window [-1, 0]: /root/capsule/scratch/AUC_results/AUC_ecephys_753125_2024-10-09_10-50-19_sorted_2024-11-09_20-03-58_rewarded_trials_unrewarded_trials_TW_-1_0.zarr
#
# ==============================
# Session: ecephys_753125_2024-10-10_14-41-23_sorted_2024-11-09_20-18-36
# ==============================
#   rewarded_trials: 270 trials
#   unrewarded_trials: 364 trials
#     ✔ Finished AUC time window [0.3, 2]: /root/capsule/scratch/AUC_results/AUC_ecephys_753125_2024-10-10_14-41-23_sorted_2024-11-09_20-18-36_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     ✔ Finished AUC time window [-1, 0]: /root/capsule/scratch/AUC_results/AUC_ecephys_753125_2024-10-10_14-41-23_sorted_2024-11-09_20-18-36_rewarded_trials_unrewarded_trials_TW_-1_0.zarr
#
# ==============================
# Session: ecephys_753125_2024-10-14_15-37-15_sorted_2024-11-09_20-07-38
# ==============================
#   rewarded_trials: 309 trials
#   unrewarded_trials: 314 trials
#     ✔ Finished AUC time window [0.3, 2]: /root/capsule/scratch/AUC_results/AUC_ecephys_753125_2024-10-14_15-37-15_sorted_2024-11-09_20-07-38_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     ✔ Finished AUC time window [-1, 0]: /root/capsule/scratch/AUC_results/AUC_ecephys_753125_2024-10-14_15-37-15_sorted_2024-11-09_20-07-38_rewarded_trials_unrewarded_trials_TW_-1_0.zarr
#
# ==============================
# Session: ecephys_753125_2024-10-15_16-16-22_sorted_2024-11-09_19-57-50
# ==============================
#   rewarded_trials: 245 trials
#   unrewarded_trials: 384 trials
#     ✔ Finished AUC time window [0.3, 2]: /root/capsule/scratch/AUC_results/AUC_ecephys_753125_2024-10-15_16-16-22_sorted_2024-11-09_19-57-50_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     ✔ Finished AUC time window [-1, 0]: /root/capsule/scratch/AUC_results/AUC_ecephys_753125_2024-10-15_16-16-22_sorted_2024-11-09_19-57-50_rewarded_trials_unrewarded_trials_TW_-1_0.zarr
#
# ==============================
# Session: ecephys_753126_2024-10-10_17-51-24_sorted_2025-02-21_13-56-40
# ==============================
#   rewarded_trials: 224 trials
#   unrewarded_trials: 272 trials
#     ✔ Finished AUC time window [0.3, 2]: /root/capsule/scratch/AUC_results/AUC_ecephys_753126_2024-10-10_17-51-24_sorted_2025-02-21_13-56-40_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     ✔ Finished AUC time window [-1, 0]: /root/capsule/scratch/AUC_results/AUC_ecephys_753126_2024-10-10_17-51-24_sorted_2025-02-21_13-56-40_rewarded_trials_unrewarded_trials_TW_-1_0.zarr
#
# ==============================
# Session: ecephys_753126_2024-10-11_13-14-24_sorted_2024-11-09_19-18-21
# ==============================
#   rewarded_trials: 266 trials
#   unrewarded_trials: 309 trials
#     ✔ Finished AUC time window [0.3, 2]: /root/capsule/scratch/AUC_results/AUC_ecephys_753126_2024-10-11_13-14-24_sorted_2024-11-09_19-18-21_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     ✔ Finished AUC time window [-1, 0]: /root/capsule/scratch/AUC_results/AUC_ecephys_753126_2024-10-11_13-14-24_sorted_2024-11-09_19-18-21_rewarded_trials_unrewarded_trials_TW_-1_0.zarr
#
# ==============================
# Session: ecephys_753126_2024-10-15_12-20-35_sorted_2024-11-09_19-47-57
# ==============================
#   rewarded_trials: 298 trials
#   unrewarded_trials: 351 trials
#     ✔ Finished AUC time window [0.3, 2]: /root/capsule/scratch/AUC_results/AUC_ecephys_753126_2024-10-15_12-20-35_sorted_2024-11-09_19-47-57_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     ✔ Finished AUC time window [-1, 0]: /root/capsule/scratch/AUC_results/AUC_ecephys_753126_2024-10-15_12-20-35_sorted_2024-11-09_19-47-57_rewarded_trials_unrewarded_trials_TW_-1_0.zarr
#
# ==============================
# Session: ecephys_764769_2024-12-11_18-21-49_sorted_2024-12-13_10-04-48
# ==============================
#   rewarded_trials: 218 trials
#   unrewarded_trials: 222 trials
#     ✔ Finished AUC time window [0.3, 2]: /root/capsule/scratch/AUC_results/AUC_ecephys_764769_2024-12-11_18-21-49_sorted_2024-12-13_10-04-48_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     ✔ Finished AUC time window [-1, 0]: /root/capsule/scratch/AUC_results/AUC_ecephys_764769_2024-12-11_18-21-49_sorted_2024-12-13_10-04-48_rewarded_trials_unrewarded_trials_TW_-1_0.zarr
#
# ==============================
# Session: ecephys_764769_2024-12-12_16-05-00_sorted_2024-12-13_10-34-23
# ==============================
#   rewarded_trials: 164 trials
#   unrewarded_trials: 206 trials
#     ✔ Finished AUC time window [0.3, 2]: /root/capsule/scratch/AUC_results/AUC_ecephys_764769_2024-12
trials
#     ✔ Finished AUC time window [0.3, 2]: /root/capsule/scratch/AUC_results/AUC_ecephys_781469_2025-03-27_18-45-35_sorted_2025-03-30_16-18-11_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     ✔ Finished AUC time window [-1, 0]: /root/capsule/scratch/AUC_results/AUC_ecephys_781469_2025-03-27_18-45-35_sorted_2025-03-30_16-18-11_rewarded_trials_unrewarded_trials_TW_-1_0.zarr
#
# ==============================
# Session: ecephys_781469_2025-03-29_10-46-53_sorted_2025-03-30_05-48-42
# ==============================
#   rewarded_trials: 145 trials
#   unrewarded_trials: 80 trials
#     ✔ Finished AUC time window [0.3, 2]: /root/capsule/scratch/AUC_results/AUC_ecephys_781469_2025-03-29_10-46-53_sorted_2025-03-30_05-48-42_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     ✔ Finished AUC time window [-1, 0]: /root/capsule/scratch/AUC_results/AUC_ecephys_781469_2025-03-29_10-46-53_sorted_2025-03-30_05-48-42_rewarded_trials_unrewarded_trials_TW_-1_0.zarr
#
# ==============================
# Session: ecephys_781471_2025-03-27_13-39-06_sorted_2025-03-31_11-52-53
# ==============================
#   rewarded_trials: 316 trials
#   unrewarded_trials: 547 trials
#     ✔ Finished AUC time window [0.3, 2]: /root/capsule/scratch/AUC_results/AUC_ecephys_781471_2025-03-27_13-39-06_sorted_2025-03-31_11-52-53_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     ✔ Finished AUC time window [-1, 0]: /root/capsule/scratch/AUC_results/AUC_ecephys_781471_2025-03-27_13-39-06_sorted_2025-03-31_11-52-53_rewarded_trials_unrewarded_trials_TW_-1_0.zarr
#
# ==============================
# Session: ecephys_781471_2025-03-28_15-06-14_sorted_2025-03-31_14-10-16
# ==============================
#   rewarded_trials: 306 trials
#   unrewarded_trials: 465 trials
#     ✔ Finished AUC time window [0.3, 2]: /root/capsule/scratch/AUC_results/AUC_ecephys_781471_2025-03-28_15-06-14_sorted_2025-03-31_14-10-16_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     ✔ Finished AUC time window [-1, 0]: /root/capsule/scratch/AUC_results/AUC_ecephys_781471_2025-03-28_15-06-14_sorted_2025-03-31_14-10-16_rewarded_trials_unrewarded_trials_TW_-1_0.zarr
#
# ==============================
# Session: ecephys_781471_2025-03-31_14-33-03_sorted_2025-04-01_15-50-16
# ==============================
#   rewarded_trials: 318 trials
#   unrewarded_trials: 492 trials
#     ✔ Finished AUC time window [0.3, 2]: /root/capsule/scratch/AUC_results/AUC_ecephys_781471_2025-03-31_14-33-03_sorted_2025-04-01_15-50-16_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     ✔ Finished AUC time window [-1, 0]: /root/capsule/scratch/AUC_results/AUC_ecephys_781471_2025-03-31_14-33-03_sorted_2025-04-01_15-50-16_rewarded_trials_unrewarded_trials_TW_-1_0.zarr
#
# ==============================
# Session: ecephys_795393_2025-09-11_20-05-17_sorted_2025-10-29_15-06-02
# ==============================
#   rewarded_trials: 309 trials
#   unrewarded_trials: 294 trials
#     ✔ Finished AUC time window [0.3, 2]: /root/capsule/scratch/AUC_results/AUC_ecephys_795393_2025-09-11_20-05-17_sorted_2025-10-29_15-06-02_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     ✔ Finished AUC time window [-1, 0]: /root/capsule/scratch/AUC_results/AUC_ecephys_795393_2025-09-11_20-05-17_sorted_2025-10-29_15-06-02_rewarded_trials_unrewarded_trials_TW_-1_0.zarr
#
# ==============================
# Session: ecephys_795393_2025-09-15_13-05-25_sorted_2025-10-29_20-10-36
# ==============================
#   rewarded_trials: 301 trials
#   unrewarded_trials: 275 trials
#     ✔ Finished AUC time window [0.3, 2]: /root/capsule/scratch/AUC_results/AUC_ecephys_795393_2025-09-15_13-05-25_sorted_2025-10-29_20-10-36_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     ✔ Finished AUC time window [-1, 0]: /root/capsule/scratch/AUC_results/AUC_ecephys_795393_2025-09-15_13-05-25_sorted_2025-10-29_20-10-36_rewarded_trials_unrewarded_trials_TW_-1_0.zarr
#
# ==============================
# Session: ecephys_795396_2025-09-20_13-11-19_sorted_2025-10-29_20-43-11
# ==============================
#   rewarded_trials: 264 trials
#   unrewarded_trials: 379 trials
#     ✔ Finished AUC time window [0.3, 2]: /root/capsule/scratch/AUC_results/AUC_ecephys_795396_2025-09-20_13-11-19_sorted_2025-10-29_20-43-11_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     ✔ Finished AUC time window [-1, 0]: /root/capsule/scratch/AUC_results/AUC_ecephys_795396_2025-09-20_13-11-19_sorted_2025-10-29_20-43-11_rewarded_trials_unrewarded_trials_TW_-1_0.zarr
#
# ==============================
# All AUC calculations done (all units).
# ==============================
# Failed items:
#  - ('ecephys_764787_2024-12-10_13-42-03_sorted_2025-01-24_15-52-45', 'load_failure', 'Zarr folder not found: /root/capsule/scratch/psth_results/ecephys_764787_2024-12-10_13-42-03_sorted_2025-01-24_15-52-45_0.2s.zarr')
#  - ('ecephys_769882_2025-01-28_19-07-31_sorted_2025-01-29_04-56-02', 'load_failure', 'Zarr folder not found: /root/capsule/scratch/psth_results/ecephys_769882_2025-01-28_19-07-31_sorted_2025-01-29_04-56-02_0.2s.zarr')
#  - ('ecephys_776293_2025-02-20_14-03-10_sorted_2025-03-30_03-39-17', 'load_failure', 'Zarr folder not found: /root/capsule/scratch/psth_results/ecephys_776293_2025-02-20_14-03-10_sorted_2025-03-30_03-39-17_0.2s.zarr')

# %%
from pathlib import Path
from calculate_auc import auto_combine_all_auc_patterns

combined_map = auto_combine_all_auc_patterns(
    root_dir=Path("/root/capsule/scratch/AUC_results"),
    overwrite=False,   # set True if you want to regenerate combined files
)

combined_map
# Out:
# Detected patterns:
#   Pattern: rewarded_trials_unrewarded_trials_TW_-1_0.zarr  (n_files=38)
rewarded_trials_unrewarded_trials_TW_-1_0.zarr
#   → session: ecephys_795393_2025-09-11_20-05-17_sorted_2025-10-29_15-06-02
#
# Loading: /root/capsule/scratch/AUC_results/AUC_ecephys_795393_2025-09-15_13-05-25_sorted_2025-10-29_20-10-36_rewarded_trials_unrewarded_trials_TW_-1_0.zarr
#   → session: ecephys_795393_2025-09-15_13-05-25_sorted_2025-10-29_20-10-36
#
# Loading: /root/capsule/scratch/AUC_results/AUC_ecephys_795396_2025-09-20_13-11-19_sorted_2025-10-29_20-43-11_rewarded_trials_unrewarded_trials_TW_-1_0.zarr
#   → session: ecephys_795396_2025-09-20_13-11-19_sorted_2025-10-29_20-43-11
#
# Concatenating along 'unit'...
# Combined dataset variables and shapes:
#   auc_mean: (24100,) (dtype=float64)
#   auc_repeats: (100, 24100) (dtype=float64)
#   auc_std: (24100,) (dtype=float64)
#   meta_brain_region: (24100,) (dtype=object)
#   meta_ccf_location: (24100,) (dtype=object)
#   meta_device_name: (24100,) (dtype=object)
#   meta_session_id: (24100,) (dtype=object)
#   meta_sorted_session_name: (24100,) (dtype=object)
#   Casting data_var 'meta_brain_region' to str (object dtype detected)
#   Casting data_var 'meta_ccf_location' to str (object dtype detected)
#   Casting data_var 'meta_device_name' to str (object dtype detected)
#   Casting data_var 'meta_session_id' to str (object dtype detected)
#   Casting data_var 'meta_sorted_session_name' to str (object dtype detected)
#
# Saving combined dataset to: /root/capsule/scratch/AUC_results/AUC_combined_rewarded_trials_unrewarded_trials_TW_-1_0_by_unit.zarr
# ✔ Combined file saved successfully.
#   ✔ Finished combining pattern 'rewarded_trials_unrewarded_trials_TW_-1_0.zarr' → /root/capsule/scratch/AUC_results/AUC_combined_rewarded_trials_unrewarded_trials_TW_-1_0_by_unit.zarr
#
# === Combining pattern: rewarded_trials_unrewarded_trials_TW_0.3_2.zarr ===
#   Files (38):
#     - AUC_ecephys_753124_2024-12-10_17-24-56_sorted_2024-12-13_09-48-25_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     - AUC_ecephys_753125_2024-10-09_10-50-19_sorted_2024-11-09_20-03-58_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     - AUC_ecephys_753125_2024-10-10_14-41-23_sorted_2024-11-09_20-18-36_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     - AUC_ecephys_753125_2024-10-14_15-37-15_sorted_2024-11-09_20-07-38_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     - AUC_ecephys_753125_2024-10-15_16-16-22_sorted_2024-11-09_19-57-50_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     - AUC_ecephys_753126_2024-10-10_17-51-24_sorted_2025-02-21_13-56-40_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     - AUC_ecephys_753126_2024-10-11_13-14-24_sorted_2024-11-09_19-18-21_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     - AUC_ecephys_753126_2024-10-15_12-20-35_sorted_2024-11-09_19-47-57_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     - AUC_ecephys_764769_2024-12-11_18-21-49_sorted_2024-12-13_10-04-48_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     - AUC_ecephys_764769_2024-12-12_16-05-00_sorted_2024-12-13_10-34-23_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     - AUC_ecephys_764769_2024-12-13_15-41-07_sorted_2024-12-17_18-00-23_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     - AUC_ecephys_764787_2024-12-11_15-01-15_sorted_2025-02-21_17-11-57_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     - AUC_ecephys_764787_2024-12-12_11-54-14_sorted_2024-12-13_10-39-18_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     - AUC_ecephys_764787_2024-12-13_18-27-42_sorted_2024-12-17_18-31-24_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     - AUC_ecephys_764790_2024-12-17_16-57-52_sorted_2024-12-20_18-46-41_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     - AUC_ecephys_764790_2024-12-18_12-14-41_sorted_2024-12-21_23-37-20_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     - AUC_ecephys_764790_2024-12-19_16-11-34_sorted_2025-02-21_14-46-33_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     - AUC_ecephys_764790_2024-12-20_16-56-37_sorted_2024-12-22_00-06-37_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     - AUC_ecephys_764791_2025-01-14_12-04-05_sorted_2025-04-24_18-24-08_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     - AUC_ecephys_764791_2025-01-15_13-08-58_sorted_2025-01-16_11-46-50_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     - AUC_ecephys_764791_2025-01-16_12-50-17_sorted_2025-04-25_14-11-37_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     - AUC_ecephys_769884_2025-01-14_14-53-24_sorted_2025-01-24_14-20-13_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     - AUC_ecephys_769884_2025-01-15_16-12-59_sorted_2025-04-24_17-11-57_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     - AUC_ecephys_769884_2025-01-16_18-33-11_sorted_2025-04-24_19-24-23_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#     - AUC_ecephys
#
# Loading: /root/capsule/scratch/AUC_results/AUC_ecephys_776293_2025-02-18_12-51-36_sorted_2025-03-30_05-50-33_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#   → session: ecephys_776293_2025-02-18_12-51-36_sorted_2025-03-30_05-50-33
#
# Loading: /root/capsule/scratch/AUC_results/AUC_ecephys_776293_2025-02-19_14-01-07_sorted_2025-03-30_08-55-28_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#   → session: ecephys_776293_2025-02-19_14-01-07_sorted_2025-03-30_08-55-28
#
# Loading: /root/capsule/scratch/AUC_results/AUC_ecephys_780618_2025-04-15_13-30-58_sorted_2025-04-18_12-52-04_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#   → session: ecephys_780618_2025-04-15_13-30-58_sorted_2025-04-18_12-52-04
#
# Loading: /root/capsule/scratch/AUC_results/AUC_ecephys_780618_2025-04-16_15-54-21_sorted_2025-04-18_12-51-23_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#   → session: ecephys_780618_2025-04-16_15-54-21_sorted_2025-04-18_12-51-23
#
# Loading: /root/capsule/scratch/AUC_results/AUC_ecephys_780618_2025-04-17_13-48-57_sorted_2025-11-07_16-27-28_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#   → session: ecephys_780618_2025-04-17_13-48-57_sorted_2025-11-07_16-27-28
#
# Loading: /root/capsule/scratch/AUC_results/AUC_ecephys_781469_2025-03-27_18-45-35_sorted_2025-03-30_16-18-11_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#   → session: ecephys_781469_2025-03-27_18-45-35_sorted_2025-03-30_16-18-11
#
# Loading: /root/capsule/scratch/AUC_results/AUC_ecephys_781469_2025-03-29_10-46-53_sorted_2025-03-30_05-48-42_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#   → session: ecephys_781469_2025-03-29_10-46-53_sorted_2025-03-30_05-48-42
#
# Loading: /root/capsule/scratch/AUC_results/AUC_ecephys_781471_2025-03-27_13-39-06_sorted_2025-03-31_11-52-53_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#   → session: ecephys_781471_2025-03-27_13-39-06_sorted_2025-03-31_11-52-53
#
# Loading: /root/capsule/scratch/AUC_results/AUC_ecephys_781471_2025-03-28_15-06-14_sorted_2025-03-31_14-10-16_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#   → session: ecephys_781471_2025-03-28_15-06-14_sorted_2025-03-31_14-10-16
#
# Loading: /root/capsule/scratch/AUC_results/AUC_ecephys_781471_2025-03-31_14-33-03_sorted_2025-04-01_15-50-16_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#   → session: ecephys_781471_2025-03-31_14-33-03_sorted_2025-04-01_15-50-16
#
# Loading: /root/capsule/scratch/AUC_results/AUC_ecephys_795393_2025-09-11_20-05-17_sorted_2025-10-29_15-06-02_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#   → session: ecephys_795393_2025-09-11_20-05-17_sorted_2025-10-29_15-06-02
#
# Loading: /root/capsule/scratch/AUC_results/AUC_ecephys_795393_2025-09-15_13-05-25_sorted_2025-10-29_20-10-36_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#   → session: ecephys_795393_2025-09-15_13-05-25_sorted_2025-10-29_20-10-36
#
# Loading: /root/capsule/scratch/AUC_results/AUC_ecephys_795396_2025-09-20_13-11-19_sorted_2025-10-29_20-43-11_rewarded_trials_unrewarded_trials_TW_0.3_2.zarr
#   → session: ecephys_795396_2025-09-20_13-11-19_sorted_2025-10-29_20-43-11
#
# Concatenating along 'unit'...
# Combined dataset variables and shapes:
#   auc_mean: (24100,) (dtype=float64)
#   auc_repeats: (100, 24100) (dtype=float64)
#   auc_std: (24100,) (dtype=float64)
#   meta_brain_region: (24100,) (dtype=object)
#   meta_ccf_location: (24100,) (dtype=object)
#   meta_device_name: (24100,) (dtype=object)
#   meta_session_id: (24100,) (dtype=object)
#   meta_sorted_session_name: (24100,) (dtype=object)
#   Casting data_var 'meta_brain_region' to str (object dtype detected)
#   Casting data_var 'meta_ccf_location' to str (object dtype detected)
#   Casting data_var 'meta_device_name' to str (object dtype detected)
#   Casting data_var 'meta_session_id' to str (object dtype detected)
#   Casting data_var 'meta_sorted_session_name' to str (object dtype detected)
#
# Saving combined dataset to: /root/capsule/scratch/AUC_results/AUC_combined_rewarded_trials_unrewarded_trials_TW_0.3_2_by_unit.zarr
# ✔ Combined file saved successfully.
#   ✔ Finished combining pattern 'rewarded_trials_unrewarded_trials_TW_0.3_2.zarr' → /root/capsule/scratch/AUC_results/AUC_combined_rewarded_trials_unrewarded_trials_TW_0.3_2_by_unit.zarr
#
# Skip pattern 'right_choice_trials_left_choice_trials_TW_-1_0.zarr' (combined file already exists): /root/capsule/scratch/AUC_results/AUC_combined_right_choice_trials_left_choice_trials_TW_-1_0_by_unit.zarr
#
# Skip pattern 'right_choice_trials_left_choice_trials_TW_0.3_2.zarr' (combined file already exists): /root/capsule/scratch/AUC_results/AUC_combined_right_choice_trials_left_choice_trials_TW_0.3_2_by_unit.zarr
# {'rewarded_trials_unrewarded_trials_TW_-1_0.zarr': PosixPath('/root/capsule/scratch/AUC_results/AUC_combined_rewarded_trials_unrewarded_trials_TW_-1_0_by_unit.zarr'),
#  'rewarded_trials_unrewarded_trials_TW_0.3_2.zarr': PosixPath('/root/capsule/scratch/AUC_results/AUC_combined_rewarded_trials_unrewarded_trials_TW_0.3_2_by_unit.zarr'),
#  'right_choice_trials_left_choice_trials_TW_-1_0.zarr': PosixPath('/root/capsule/scratch/AUC_results/AUC_combined_right_choice_trials_left_choice_trials_TW_-1_0_by_unit.zarr'),
#  'right_choice_trials_left_choice_trials_TW_0.3_2.zarr': PosixPath('/root/capsule/scratch/AUC_results/AUC_combined_right_choice_trials_left_choice_trials_TW_0.3_2_by_unit.zarr')}

# %%
from pathlib import Path
from calculate_auc_visualization import plot_auc_cdf_by_region

combined_path = Path("/root/capsule/scratch/AUC_results") / \
    "AUC_combined_right_choice_trials_left_choice_trials_TW_-1_0_by_unit.zarr"
fig, ax, counts = plot_auc_cdf_by_region(
    combined_path,
    auc_var="auc_mean",
    region_var="meta_brain_region",
    brain_regions=[["MD"], ["MOs2/3","MOs5","MOs6a"],['SI','MA'],["PL5","PL6a","ILA5","ILA6a"]],     # NEW
    min_units_per_region=20,
    title="CDF of AUC (right vs left, TW -1–0)",
    flip_auc=True,
    flip_mode='symmetric'

)


combined_path = Path("/root/capsule/scratch/AUC_results") / \
    "AUC_combined_right_choice_trials_left_choice_trials_TW_0.3_2_by_unit.zarr"

fig, ax, counts = plot_auc_cdf_by_region(
    combined_path,
    auc_var="auc_mean",
    region_var="meta_brain_region",
    brain_regions=[["MD"], ["MOs2/3","MOs5","MOs6a"],['SI','MA'],["PL5","PL6a","ILA5","ILA6a"]],     # NEW
    min_units_per_region=20,
    title="CDF of AUC (right vs left, TW 0.3–2)",
    flip_auc=True,
    flip_mode='symmetric'

)



combined_path = Path("/root/capsule/scratch/AUC_results") / \
    "AUC_combined_rewarded_trials_unrewarded_trials_TW_-1_0_by_unit.zarr"
fig, ax, counts = plot_auc_cdf_by_region(
    combined_path,
    auc_var="auc_mean",
    region_var="meta_brain_region",
    brain_regions=[["MD"], ["MOs2/3","MOs5","MOs6a"],['SI','MA'],["PL5","PL6a","ILA5","ILA6a"]],     # NEW
    min_units_per_region=20,
    title="CDF of AUC (reward vs unreward, TW -1–0)",
    flip_auc=True,
    flip_mode='symmetric'

)


combined_path = Path("/root/capsule/scratch/AUC_results") / \
    "AUC_combined_rewarded_trials_unrewarded_trials_TW_0.3_2_by_unit.zarr"

fig, ax, counts = plot_auc_cdf_by_region(
    combined_path,
    auc_var="auc_mean",
    region_var="meta_brain_region",
    brain_regions=[["MD"], ["MOs2/3","MOs5","MOs6a"],['SI','MA'],["PL5","PL6a","ILA5","ILA6a"]],     # NEW
    min_units_per_region=20,
    title="CDF of AUC (reward vs unreward, TW 0.3–2)",
    flip_auc=True,
    flip_mode='symmetric'

)
